# %%
## Importing the Libraries

import pandas as pd ## pandas is used to manupulate the dataframe
import numpy as np ## numpy is used to do scientific calculations
import matplotlib.pyplot as plt ## matplotlib used for visualization
import seaborn as sns ## seaborn used for visualization 
import missingno as msno ## used to visualize missing values
import warnings ## used to remove warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

from sklearn.model_selection import train_test_split,cross_validate, GridSearchCV
from sklearn.preprocessing import StandardScaler,OrdinalEncoder
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression,Lasso,Ridge,BayesianRidge
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

import math
from IPython.display import Image
import warnings
warnings.filterwarnings("ignore")
sns.set(rc={"figure.figsize": (20, 15)})
sns.set_style("whitegrid")

# %%
## Importing the data

df=pd.read_csv('train.csv')

# %%
## Getting the data

df
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     127         120       RL          NaN     4928   Pave   NaN      IR1
# 1     889          20       RL         95.0    15865   Pave   NaN      IR1
# 2     793          60       RL         92.0     9920   Pave   NaN      IR1
# 3     110          20       RL        105.0    11751   Pave   NaN      IR1
# 4     422          20       RL          NaN    16635   Pave   NaN      IR1
# ...   ...         ...      ...          ...      ...    ...   ...      ...
# 1163  289          20       RL          NaN     9819   Pave   NaN      IR1
# 1164  554          20       RL         67.0     8777   Pave   NaN      Reg
# 1165  196         160       RL         24.0     2280   Pave   NaN      Reg
# 1166   31          70  C (all)         50.0     8500   Pave  Pave      Reg
# 1167  617          60       RL          NaN     7861   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3            Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 4            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1163         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1164         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1165         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1166         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1167         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         2   2007        WD         Normal     128000
# 1        10   2007        WD         Normal     268000
# 2         6   2007        WD         Normal     269790
# 3         1   2010       COD         Normal     190000
# 4         6   2009        WD         Normal     215000
# ...     ...    ...       ...            ...        ...
# 1163      2   2010        WD         Normal     122000
# 1164      5   2009        WD         Normal     108000
# 1165      7   2009        WD         Normal     148500
# 1166      7   2008        WD         Normal      40000
# 1167      6   2006        WD         Normal     183200
#
# [1168 rows x 81 columns]

# %%
df.head(10).style.background_gradient(cmap = "viridis")
# Out:
# <style type="text/css">
# #T_d5e27_row0_col0 {
#   background-color: #46075a;
#   color: #f1f1f1;
# }
# #T_d5e27_row0_col1, #T_d5e27_row0_col49, #T_d5e27_row0_col56, #T_d5e27_row1_col17, #T_d5e27_row1_col36, #T_d5e27_row1_col38, #T_d5e27_row1_col43, #T_d5e27_row1_col46, #T_d5e27_row1_col47, #T_d5e27_row1_col49, #T_d5e27_row1_col51, #T_d5e27_row1_col56, #T_d5e27_row1_col67, #T_d5e27_row1_col70, #T_d5e27_row2_col47, #T_d5e27_row2_col49, #T_d5e27_row2_col50, #T_d5e27_row2_col56, #T_d5e27_row2_col80, #T_d5e27_row3_col3, #T_d5e27_row3_col26, #T_d5e27_row3_col37, #T_d5e27_row3_col49, #T_d5e27_row3_col56, #T_d5e27_row3_col77, #T_d5e27_row4_col4, #T_d5e27_row4_col18, #T_d5e27_row4_col48, #T_d5e27_row4_col49, #T_d5e27_row4_col56, #T_d5e27_row4_col66, #T_d5e27_row5_col0, #T_d5e27_row5_col19, #T_d5e27_row5_col20, #T_d5e27_row5_col44, #T_d5e27_row5_col49, #T_d5e27_row5_col50, #T_d5e27_row5_col51, #T_d5e27_row5_col54, #T_d5e27_row5_col56, #T_d5e27_row5_col59, #T_d5e27_row5_col61, #T_d5e27_row5_col62, #T_d5e27_row5_col76, #T_d5e27_row6_col34, #T_d5e27_row6_col47, #T_d5e27_row6_col50, #T_d5e27_row6_col56, #T_d5e27_row6_col77, #T_d5e27_row7_col47, #T_d5e27_row7_col49, #T_d5e27_row7_col56, #T_d5e27_row8_col18, #T_d5e27_row8_col47, #T_d5e27_row8_col68, #T_d5e27_row8_col75 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_d5e27_row0_col3, #T_d5e27_row4_col3, #T_d5e27_row6_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_d5e27_row0_col4, #T_d5e27_row0_col26, #T_d5e27_row0_col36, #T_d5e27_row0_col44, #T_d5e27_row0_col45, #T_d5e27_row0_col46, #T_d5e27_row0_col47, #T_d5e27_row0_col48, #T_d5e27_row0_col50, #T_d5e27_row0_col51, #T_d5e27_row0_col52, #T_d5e27_row0_col54, #T_d5e27_row0_col66, #T_d5e27_row0_col68, #T_d5e27_row0_col69, #T_d5e27_row0_col70, #T_d5e27_row0_col71, #T_d5e27_row0_col75, #T_d5e27_row1_col1, #T_d5e27_row1_col26, #T_d5e27_row1_col44, #T_d5e27_row1_col45, #T_d5e27_row1_col48, #T_d5e27_row1_col50, #T_d5e27_row1_col52, #T_d5e27_row1_col68, #T_d5e27_row1_col69, #T_d5e27_row1_col71, #T_d5e27_row1_col75, #T_d5e27_row2_col26, #T_d5e27_row2_col36, #T_d5e27_row2_col45, #T_d5e27_row2_col48, #T_d5e27_row2_col52, #T_d5e27_row2_col68, #T_d5e27_row2_col69, #T_d5e27_row2_col70, #T_d5e27_row2_col71, #T_d5e27_row2_col75, #T_d5e27_row3_col0, #T_d5e27_row3_col1, #T_d5e27_row3_col36, #T_d5e27_row3_col44, #T_d5e27_row3_col45, #T_d5e27_row3_col47, #T_d5e27_row3_col48, #T_d5e27_row3_col50, #T_d5e27_row3_col52, #T_d5e27_row3_col66, #T_d5e27_row3_col68, #T_d5e27_row3_col69, #T_d5e27_row3_col70, #T_d5e27_row3_col71, #T_d5e27_row3_col75, #T_d5e27_row3_col76, #T_d5e27_row4_col1, #T_d5e27_row4_col36, #T_d5e27_row4_col44, #T_d5e27_row4_col45, #T_d5e27_row4_col47, #T_d5e27_row4_col50, #T_d5e27_row4_col52, #T_d5e27_row4_col67, #T_d5e27_row4_col68, #T_d5e27_row4_col69, #T_d5e27_row4_col70, #T_d5e27_row4_col71, #T_d5e27_row4_col75, #T_d5e27_row5_col3, #T_d5e27_row5_col26, #T_d5e27_row5_col34, #T_d5e27_row5_col36, #T_d5e27_row5_col45, #T_d5e27_row5_col47, #T_d5e27_row5_col48, #T_d5e27_row5_col52, #T_d5e27_row5_col68, #T_d5e27_row5_col69, #T_d5e27_row5_col70, #T_d5e27_row5_col71, #T_d5e27_row5_col75, #T_d5e27_row5_col77, #T_d5e27_row6_col1, #T_d5e27_row6_col17, #T_d5e27_row6_col36, #T_d5e27_row6_col37, #T_d5e27_row6_col44, #T_d5e27_row6_col45, #T_d5e27_row6_col48, #T_d5e27_row6_col49, #T_d5e27_row6_col52, #T_d5e27_row6_col54, #T_d5e27_row6_col66, #T_d5e27_row6_col67, #T_d5e27_row6_col68, #T_d5e27_row6_col69, #T_d5e27_row6_col71, #T_d5e27_row6_col75, #T_d5e27_row7_col1, #T_d5e27_row7_col17, #T_d5e27_row7_col18, #T_d5e27_row7_col44, #T_d5e27_row7_col45, #T_d5e27_row7_col48, #T_d5e27_row7_col50, #T_d5e27_row7_col52, #T_d5e27_row7_col66, #T_d5e27_row7_col67, #T_d5e27_row7_col68, #T_d5e27_row7_col69, #T_d5e27_row7_col70, #T_d5e27_row7_col71, #T_d5e27_row7_col75, #T_d5e27_row7_col76, #T_d5e27_row7_col77, #T_d5e27_row8_col1, #T_d5e27_row8_col17, #T_d5e27_row8_col26, #T_d5e27_row8_col44, #T_d5e27_row8_col45, #T_d5e27_row8_col48, #T_d5e27_row8_col49, #T_d5e27_row8_col50, #T_d5e27_row8_col51, #T_d5e27_row8_col52, #T_d5e27_row8_col56, #T_d5e27_row8_col66, #T_d5e27_row8_col67, #T_d5e27_row8_col69, #T_d5e27_row8_col70, #T_d5e27_row8_col71, #T_d5e27_row9_col17, #T_d5e27_row9_col19, #T_d5e27_row9_col20, #T_d5e27_row9_col26, #T_d5e27_row9_col36, #T_d5e27_row9_col38, #T_d5e27_row9_col43, #T_d5e27_row9_col45, #T_d5e27_row9_col47, #T_d5e27_row9_col48, #T_d5e27_row9_col49, #T_d5e27_row9_col50, #T_d5e27_row9_col51, #T_d5e27_row9_col52, #T_d5e27_row9_col56, #T_d5e27_row9_col59, #T_d5e27_row9_col61, #T_d5e27_row9_col62, #T_d5e27_row9_col67, #T_d5e27_row9_col69, #T_d5e27_row9_col70, #T_d5e27_row9_col71, #T_d5e27_row9_col75, #T_d5e27_row9_col80 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_d5e27_row0_col17, #T_d5e27_row0_col18, #T_d5e27_row2_col18, #T_d5e27_row3_col17, #T_d5e27_row4_col17, #T_d5e27_row5_col18, #T_d5e27_row9_col18 {
#   background-color: #31688e;
#   color: #f1f1f1;
# }
# #T_d5e27_row0_col19 {
#   background-color: #218e8d;
#   color: #f1f1f1;
# }
# #T_d5e27_row0_col20 {
#   background-color: #24878e;
#   color: #f1f1f1;
# }
# #T_d5e27_row0_col34, #T_d5e27_row0_col43 {
#   background-color: #482173;
#   color: #f1f1f1;
# }
# #T_d5e27_row0_col37 {
#   background-color: #8bd646;
#   color: #000000;
# }
# #T_d5e27_row0_col38 {
#   background-color: #433d84;
#   color: #f1f1f1;
# }
# #T_d5e27_row0_col59, #T_d5e27_row3_col19, #T_d5e27_row3_col59, #T_d5e27_row4_col19, #T_d5e27_row4_col46, #T_d5e27_row4_col59 {
#   background-color: #20928c;
#   color: #f1f1f1;
# }
# #T_d5e27_row0_col61, #T_d5e27_row1_col61, #T_d5e27_row2_col51, #T_d5e27_row2_col61, #T_d5e27_row2_col76, #T_d5e27_row3_col51, #T_d5e27_row3_col54, #T_d5e27_row3_col61, #T_d5e27_row4_col51, #T_d5e27_row4_col61, #T_d5e27_row4_col76, #T_d5e27_row6_col51, #T_d5e27_row6_col61, #T_d5e27_row7_col51, #T_d5e27_row7_col61, #T_d5e27_row8_col61, #T_d5e27_row9_col77 {
#   background-color: #21918c;
#   color: #f1f1f1;
# }
# #T_d5e27_row0_col62 {
#   background-color: #32658e;
#   color: #f1f1f1;
# }
# #T_d5e27_row0_col67 {
#   background-color: #f8e621;
#   color: #000000;
# }
# #T_d5e27_row0_col76 {
#   background-color: #482475;
#   color: #f1f1f1;
# }
# #T_d5e27_row0_col77, #T_d5e27_row1_col77, #T_d5e27_row2_col77, #T_d5e27_row4_col37, #T_d5e27_row8_col54, #T_d5e27_row8_col77, #T_d5e27_row9_col54 {
#   background-color: #3b528b;
#   color: #f1f1f1;
# }
# #T_d5e27_row0_col80 {
#   background-color: #48186a;
#   color: #f1f1f1;
# }
# #T_d5e27_row1_col0 {
#   background-color: #4cc26c;
#   color: #000000;
# }
# #T_d5e27_row1_col3 {
#   background-color: #73d056;
#   color: #000000;
# }
# #T_d5e27_row1_col4 {
#   background-color: #d5e21a;
#   color: #000000;
# }
# #T_d5e27_row1_col18, #T_d5e27_row2_col17, #T_d5e27_row3_col18, #T_d5e27_row5_col17, #T_d5e27_row5_col80, #T_d5e27_row6_col18 {
#   background-color: #35b779;
#   color: #f1f1f1;
# }
# #T_d5e27_row1_col19, #T_d5e27_row1_col59, #T_d5e27_row9_col44 {
#   background-color: #2b758e;
#   color: #f1f1f1;
# }
# #T_d5e27_row1_col20 {
#   background-color: #2e6e8e;
#   color: #f1f1f1;
# }
# #T_d5e27_row1_col34 {
#   background-color: #38588c;
#   color: #f1f1f1;
# }
# #T_d5e27_row1_col37 {
#   background-color: #c2df23;
#   color: #000000;
# }
# #T_d5e27_row1_col54, #T_d5e27_row2_col54, #T_d5e27_row2_col66, #T_d5e27_row4_col54, #T_d5e27_row4_col77, #T_d5e27_row5_col37, #T_d5e27_row7_col54 {
#   background-color: #5ec962;
#   color: #000000;
# }
# #T_d5e27_row1_col62 {
#   background-color: #b0dd2f;
#   color: #000000;
# }
# #T_d5e27_row1_col66, #T_d5e27_row9_col34 {
#   background-color: #30698e;
#   color: #f1f1f1;
# }
# #T_d5e27_row1_col76, #T_d5e27_row2_col44, #T_d5e27_row9_col76 {
#   background-color: #bddf26;
#   color: #000000;
# }
# #T_d5e27_row1_col80 {
#   background-color: #f6e620;
#   color: #000000;
# }
# #T_d5e27_row2_col0, #T_d5e27_row2_col67 {
#   background-color: #28ae80;
#   color: #f1f1f1;
# }
# #T_d5e27_row2_col1, #T_d5e27_row5_col1, #T_d5e27_row6_col76 {
#   background-color: #2a788e;
#   color: #f1f1f1;
# }
# #T_d5e27_row2_col3 {
#   background-color: #50c46a;
#   color: #000000;
# }
# #T_d5e27_row2_col4, #T_d5e27_row9_col0 {
#   background-color: #277f8e;
#   color: #f1f1f1;
# }
# #T_d5e27_row2_col19, #T

# %% [markdown]
# ###### There are 1460 rows and 81 columns in this dataset

# %%
## Basic Checks

df.head()  ## getting first five rows
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  127         120       RL          NaN     4928   Pave   NaN      IR1
# 1  889          20       RL         95.0    15865   Pave   NaN      IR1
# 2  793          60       RL         92.0     9920   Pave   NaN      IR1
# 3  110          20       RL        105.0    11751   Pave   NaN      IR1
# 4  422          20       RL          NaN    16635   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 4         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2007        WD         Normal     128000
# 1     10   2007        WD         Normal     268000
# 2      6   2007        WD         Normal     269790
# 3      1   2010       COD         Normal     190000
# 4      6   2009        WD         Normal     215000
#
# [5 rows x 81 columns]

# %%
df.tail() ## getting last five rows
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1163  289          20       RL          NaN     9819   Pave   NaN      IR1
# 1164  554          20       RL         67.0     8777   Pave   NaN      Reg
# 1165  196         160       RL         24.0     2280   Pave   NaN      Reg
# 1166   31          70  C (all)         50.0     8500   Pave  Pave      Reg
# 1167  617          60       RL          NaN     7861   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1163         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1164         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1165         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1166         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1167         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 1163      2   2010        WD         Normal     122000
# 1164      5   2009        WD         Normal     108000
# 1165      7   2009        WD         Normal     148500
# 1166      7   2008        WD         Normal      40000
# 1167      6   2006        WD         Normal     183200
#
# [5 rows x 81 columns]

# %%
df.describe().transpose().style.background_gradient(cmap = "magma")
# Out:
# <style type="text/css">
# #T_6e8c7_row0_col0, #T_6e8c7_row1_col0, #T_6e8c7_row3_col0, #T_6e8c7_row4_col0, #T_6e8c7_row5_col0, #T_6e8c7_row6_col0, #T_6e8c7_row7_col0, #T_6e8c7_row9_col0, #T_6e8c7_row10_col0, #T_6e8c7_row11_col0, #T_6e8c7_row12_col0, #T_6e8c7_row13_col0, #T_6e8c7_row14_col0, #T_6e8c7_row15_col0, #T_6e8c7_row16_col0, #T_6e8c7_row17_col0, #T_6e8c7_row18_col0, #T_6e8c7_row19_col0, #T_6e8c7_row20_col0, #T_6e8c7_row21_col0, #T_6e8c7_row22_col0, #T_6e8c7_row23_col0, #T_6e8c7_row24_col0, #T_6e8c7_row26_col0, #T_6e8c7_row27_col0, #T_6e8c7_row28_col0, #T_6e8c7_row29_col0, #T_6e8c7_row30_col0, #T_6e8c7_row31_col0, #T_6e8c7_row32_col0, #T_6e8c7_row33_col0, #T_6e8c7_row34_col0, #T_6e8c7_row35_col0, #T_6e8c7_row36_col0, #T_6e8c7_row37_col0, #T_6e8c7_row37_col1, #T_6e8c7_row37_col2, #T_6e8c7_row37_col3, #T_6e8c7_row37_col4, #T_6e8c7_row37_col5, #T_6e8c7_row37_col6, #T_6e8c7_row37_col7 {
#   background-color: #fcfdbf;
#   color: #000000;
# }
# #T_6e8c7_row0_col1, #T_6e8c7_row0_col2, #T_6e8c7_row0_col5, #T_6e8c7_row0_col6, #T_6e8c7_row9_col2, #T_6e8c7_row9_col7, #T_6e8c7_row11_col2, #T_6e8c7_row12_col1, #T_6e8c7_row12_col2, #T_6e8c7_row12_col4, #T_6e8c7_row12_col5, #T_6e8c7_row12_col6, #T_6e8c7_row13_col1, #T_6e8c7_row13_col2, #T_6e8c7_row13_col4, #T_6e8c7_row13_col5, #T_6e8c7_row13_col6, #T_6e8c7_row13_col7, #T_6e8c7_row14_col2, #T_6e8c7_row16_col2, #T_6e8c7_row16_col7, #T_6e8c7_row34_col2 {
#   background-color: #010005;
#   color: #f1f1f1;
# }
# #T_6e8c7_row0_col3, #T_6e8c7_row0_col4, #T_6e8c7_row0_col7, #T_6e8c7_row1_col1, #T_6e8c7_row1_col2, #T_6e8c7_row1_col3, #T_6e8c7_row1_col4, #T_6e8c7_row1_col5, #T_6e8c7_row1_col6, #T_6e8c7_row1_col7, #T_6e8c7_row2_col0, #T_6e8c7_row2_col1, #T_6e8c7_row2_col2, #T_6e8c7_row2_col3, #T_6e8c7_row2_col4, #T_6e8c7_row2_col5, #T_6e8c7_row2_col6, #T_6e8c7_row2_col7, #T_6e8c7_row4_col1, #T_6e8c7_row4_col2, #T_6e8c7_row4_col3, #T_6e8c7_row4_col4, #T_6e8c7_row4_col5, #T_6e8c7_row4_col6, #T_6e8c7_row4_col7, #T_6e8c7_row5_col1, #T_6e8c7_row5_col2, #T_6e8c7_row5_col3, #T_6e8c7_row5_col4, #T_6e8c7_row5_col5, #T_6e8c7_row5_col6, #T_6e8c7_row5_col7, #T_6e8c7_row6_col2, #T_6e8c7_row6_col7, #T_6e8c7_row7_col2, #T_6e8c7_row7_col7, #T_6e8c7_row8_col1, #T_6e8c7_row8_col2, #T_6e8c7_row8_col3, #T_6e8c7_row8_col4, #T_6e8c7_row8_col5, #T_6e8c7_row8_col6, #T_6e8c7_row8_col7, #T_6e8c7_row9_col1, #T_6e8c7_row9_col3, #T_6e8c7_row9_col4, #T_6e8c7_row9_col5, #T_6e8c7_row9_col6, #T_6e8c7_row10_col1, #T_6e8c7_row10_col2, #T_6e8c7_row10_col3, #T_6e8c7_row10_col4, #T_6e8c7_row10_col5, #T_6e8c7_row10_col6, #T_6e8c7_row10_col7, #T_6e8c7_row11_col1, #T_6e8c7_row11_col3, #T_6e8c7_row11_col4, #T_6e8c7_row11_col5, #T_6e8c7_row11_col6, #T_6e8c7_row11_col7, #T_6e8c7_row12_col3, #T_6e8c7_row14_col1, #T_6e8c7_row14_col3, #T_6e8c7_row14_col4, #T_6e8c7_row14_col5, #T_6e8c7_row14_col6, #T_6e8c7_row14_col7, #T_6e8c7_row15_col1, #T_6e8c7_row15_col2, #T_6e8c7_row15_col3, #T_6e8c7_row15_col4, #T_6e8c7_row15_col5, #T_6e8c7_row15_col6, #T_6e8c7_row15_col7, #T_6e8c7_row17_col1, #T_6e8c7_row17_col2, #T_6e8c7_row17_col3, #T_6e8c7_row17_col4, #T_6e8c7_row17_col5, #T_6e8c7_row17_col6, #T_6e8c7_row17_col7, #T_6e8c7_row18_col1, #T_6e8c7_row18_col2, #T_6e8c7_row18_col3, #T_6e8c7_row18_col4, #T_6e8c7_row18_col5, #T_6e8c7_row18_col6, #T_6e8c7_row18_col7, #T_6e8c7_row19_col1, #T_6e8c7_row19_col2, #T_6e8c7_row19_col3, #T_6e8c7_row19_col4, #T_6e8c7_row19_col5, #T_6e8c7_row19_col6, #T_6e8c7_row19_col7, #T_6e8c7_row20_col1, #T_6e8c7_row20_col2, #T_6e8c7_row20_col3, #T_6e8c7_row20_col4, #T_6e8c7_row20_col5, #T_6e8c7_row20_col6, #T_6e8c7_row20_col7, #T_6e8c7_row21_col1, #T_6e8c7_row21_col2, #T_6e8c7_row21_col3, #T_6e8c7_row21_col4, #T_6e8c7_row21_col5, #T_6e8c7_row21_col6, #T_6e8c7_row21_col7, #T_6e8c7_row22_col1, #T_6e8c7_row22_col2, #T_6e8c7_row22_col3, #T_6e8c7_row22_col4, #T_6e8c7_row22_col5, #T_6e8c7_row22_col6, #T_6e8c7_row22_col7, #T_6e8c7_row23_col1, #T_6e8c7_row23_col2, #T_6e8c7_row23_col3, #T_6e8c7_row23_col4, #T_6e8c7_row23_col5, #T_6e8c7_row23_col6, #T_6e8c7_row23_col7, #T_6e8c7_row24_col1, #T_6e8c7_row24_col2, #T_6e8c7_row24_col3, #T_6e8c7_row24_col4, #T_6e8c7_row24_col5, #T_6e8c7_row24_col6, #T_6e8c7_row24_col7, #T_6e8c7_row25_col2, #T_6e8c7_row25_col7, #T_6e8c7_row26_col1, #T_6e8c7_row26_col2, #T_6e8c7_row26_col3, #T_6e8c7_row26_col4, #T_6e8c7_row26_col5, #T_6e8c7_row26_col6, #T_6e8c7_row26_col7, #T_6e8c7_row27_col1, #T_6e8c7_row27_col2, #T_6e8c7_row27_col3, #T_6e8c7_row27_col4, #T_6e8c7_row27_col5, #T_6e8c7_row27_col6, #T_6e8c7_row27_col7, #T_6e8c7_row28_col1, #T_6e8c7_row28_col2, #T_6e8c7_row28_col3, #T_6e8c7_row28_col4, #T_6e8c7_row28_col5, #T_6e8c7_row28_col6, #T_6e8c7_row28_col7, #T_6e8c7_row29_col1, #T_6e8c7_row29_col2, #T_6e8c7_row29_col3, #T_6e8c7_row29_col4, #T_6e8c7_row29_col5, #T_6e8c7_row29_col6, #T_6e8c7_row29_col7, #T_6e8c7_row30_col1, #T_6e8c7_row30_col2, #T_6e8c7_row30_col3, #T_6e8c7_row30_col4, #T_6e8c7_row30_col5, #T_6e8c7_row30_col6, #T_6e8c7_row30_col7, #T_6e8c7_row31_col1, #T_6e8c7_row31_col2, #T_6e8c7_row31_col3, #T_6e8c7_row31_col4, #T_6e8c7_row31_col5, #T_6e8c7_row31_col6, #T_6e8c7_row31_col7, #T_6e8c7_row32_col1, #T_6e8c7_row32_col2, #T_6e8c7_row32_col3, #T_6e8c7_row32_col4, #T_6e8c7_row32_col5, #T_6e8c7_row32_col6, #T_6e8c7_row32_col7, #T_6e8c7_row33_col1, #T_6e8c7_row33_col2, #T_6e8c7_row33_col3, #T_6e8c7_row33_col4, #T_6e8c7_row33_col5, #T_6e8c7_row33_col6, #T_6e8c7_row33_col7, #T_6e8c7_row34_col1, #T_6e8c7_row34_col3, #T_6e8c7_row34_col4, #T_6e8c7_row34_c ...
#   background-color: #000004;
#   color: #f1f1f1;
# }
# #T_6e8c7_row3_col1, #T_6e8c7_row3_col4, #T_6e8c7_row3_col5, #T_6e8c7_row7_col3, #T_6e8c7_row36_col3 {
#   background-color: #08071e;
#   color: #f1f1f1;
# }
# #T_6e8c7_row3_col2 {
#   background-color: #180f3d;
#   color: #f1f1f1;
# }
# #T_6e8c7_row3_col3 {
#   background-color: #040414;
#   color: #f1f1f1;
# }
# #T_6e8c7_row3_col6, #T_6e8c7_row6_col3, #T_6e8c7_row25_col3 {
#   background-color: #07061c;
#   color: #f1f1f1;
# }
# #T_6e8c7_row3_col7 {
#   background-color: #420f75;
#   color: #f1f1f1;
# }
# #T_6e8c7_row6_col1, #T_6e8c7_row6_col6, #T_6e8c7_row7_col1, #T_6e8c7_row7_col6, #T_6e8c7_row12_col7, #T_6e8c7_row13_col3, #T_6e8c7_row16_col1, #T_6e8c7_row16_col3, #T_6e8c7_row16_col4, #T_6e8c7_row16_col5, #T_6e8c7_row16_col6, #T_6e8c7_row25_col1, #T_6e8c7_row25_col6, #T_6e8c7_row36_col1, #T_6e8c7_row36_col6 {
#   background-color: #010106;
#   color: #f1f1f1;
# }
# #T_6e8c7_row6_col4, #T_6e8c7_row6_col5, #T_6e8c7_row7_col4, #T_6e8c7_row7_col5, #T_6e8c7_row25_col4, #T_6e8c7_row25_col5, #T_6e8c7_row36_col4, #T_6e8c7_row36_col5 {
#   background-color: #010108;
#   color: #f1f1f1;
# }
# #T_6e8c7_row8_col0 {
#   background-color: #fceeb0;
#   color: #000000;
# }
# #T_6e8c7_row25_col0 {
#   background-color: #f7705c;
#   color: #f1f1f1;
# }
# #T_6e8c7_row34_col7 {
#   background-color: #02020b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6e8c7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e8c7_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_6e8c7_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_6e8c7_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_6e8c7_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_6e8c7_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_6e8c7_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_6e8c7_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_6e8c7_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e8c7_level0_row0" class="row_heading level0 row0" >Id</th>
#       <td id="T_6e8c7_row0_col0" class="data row0 col0" >1168.000000</td>
#       <td id="T_6e8c7_row0_col1" class="data row0 col1" >724.136130</td>
#       <td id="T_6e8c7_row0_col2" class="data ro

# %%
df.info() ## getting the information from the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1168 entries, 0 to 1167
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1168 non-null   int64
#  1   MSSubClass     1168 non-null   int64
#  2   MSZoning       1168 non-null   object
#  3   LotFrontage    954 non-null    float64
#  4   LotArea        1168 non-null   int64
#  5   Street         1168 non-null   object
#  6   Alley          77 non-null     object
#  7   LotShape       1168 non-null   object
#  8   LandContour    1168 non-null   object
#  9   Utilities      1168 non-null   object
#  10  LotConfig      1168 non-null   object
#  11  LandSlope      1168 non-null   object
#  12  Neighborhood   1168 non-null   object
#  13  Condition1     1168 non-null   object
#  14  Condition2     1168 non-null   object
#  15  BldgType       1168 non-null   object
#  16  HouseStyle     1168 non-null   object
#  17  OverallQual    1168 non-null   int64
#  18  OverallCond    1168 non-null   int64
#  19  YearBuilt      1168 non-null   int64
#  20  YearRemodAdd   1168 non-null   int64
#  21  RoofStyle      1168 non-null   object
#  22  RoofMatl       1168 non-null   object
#  23  Exterior1st    1168 non-null   object
#  24  Exterior2nd    1168 non-null   object
#  25  MasVnrType     1161 non-null   object
#  26  MasVnrArea     1161 non-null   float64
#  27  ExterQual      1168 non-null   object
#  28  ExterCond      1168 non-null   object
#  29  Foundation     1168 non-null   object
#  30  BsmtQual       1138 non-null   object
#  31  BsmtCond       1138 non-null   object
#  32  BsmtExposure   1137 non-null   object
#  33  BsmtFinType1   1138 non-null   object
#  34  BsmtFinSF1     1168 non-null   int64
#  35  BsmtFinType2   1137 non-null   object
#  36  BsmtFinSF2     1168 non-null   int64
#  37  BsmtUnfSF      1168 non-null   int64
#  38  TotalBsmtSF    1168 non-null   int64
#  39  Heating        1168 non-null   object
#  40  HeatingQC      1168 non-null   object
#  41  CentralAir     1168 non-null   object
#  42  Electrical     1168 non-null   object
#  43  1stFlrSF       1168 non-null   int64
#  44  2ndFlrSF       1168 non-null   int64
#  45  LowQualFinSF   1168 non-null   int64
#  46  GrLivArea      1168 non-null   int64
#  47  BsmtFullBath   1168 non-null   int64
#  48  BsmtHalfBath   1168 non-null   int64
#  49  FullBath       1168 non-null   int64
#  50  HalfBath       1168 non-null   int64
#  51  BedroomAbvGr   1168 non-null   int64
#  52  KitchenAbvGr   1168 non-null   int64
#  53  KitchenQual    1168 non-null   object
#  54  TotRmsAbvGrd   1168 non-null   int64
#  55  Functional     1168 non-null   object
#  56  Fireplaces     1168 non-null   int64
#  57  FireplaceQu    617 non-null    object
#  58  GarageType     1104 non-null   object
#  59  GarageYrBlt    1104 non-null   float64
#  60  GarageFinish   1104 non-null   object
#  61  GarageCars     1168 non-null   int64
#  62  GarageArea     1168 non-null   int64
#  63  GarageQual     1104 non-null   object
#  64  GarageCond     1104 non-null   object
#  65  PavedDrive     1168 non-null   object
#  66  WoodDeckSF     1168 non-null   int64
#  67  OpenPorchSF    1168 non-null   int64
#  68  EnclosedPorch  1168 non-null   int64
#  69  3SsnPorch      1168 non-null   int64
#  70  ScreenPorch    1168 non-null   int64
#  71  PoolArea       1168 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          237 non-null    object
#  74  MiscFeature    44 non-null     object
#  75  MiscVal        1168 non-null   int64
#  76  MoSold         1168 non-null   int64
#  77  YrSold         1168 non-null   int64
#  78  SaleType       1168 non-null   object
#  79  SaleCondition  1168 non-null   object
#  80  SalePrice      1168 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 739.2+ KB

# %%
var_num = ["SalePrice", "OverallQual", "GrLivArea", "GarageCars", "TotalBsmtSF", "FullBath", "YearBuilt"]
sns.pairplot(df[var_num]);

# %%
sns.distplot(df["SalePrice"])
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Density'>

# %%
df["SalePrice"].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %% [markdown]
# There is a huge difference between the min and max as there are outliers and few people can afford really expensive houses

# %% [markdown]
# ### Using log to make te sale Price distribution a normal distribution

# %%
df["LogSalePrice"] = np.log10(df["SalePrice"])
sns.distplot(df["LogSalePrice"],color = 'r')
# Out:
# <AxesSubplot:xlabel='LogSalePrice', ylabel='Density'>

# %%
## checking if there is any duplicate data

df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ###### There is no duplicate data moving to next step

# %%
## Analysing if there is any null values

pd.options.display.max_rows=None ## shows all the rows
df.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# CentralAir          0
# Electrical          1
# 1stFlrSF            0
# 2ndFlrSF            0
# LowQualFinSF        0
# GrLivArea           0
# BsmtFullBath        0
# BsmtHalfBath        0
# FullBath            0
# HalfBath            0
# BedroomAbvGr        0
# KitchenAbvGr        0
# KitchenQual         0
# TotRmsAbvGrd        0
# Functional          0
# Fireplaces          0
# FireplaceQu       690
# GarageType         81
# GarageYrBlt        81
# GarageFinish       81
# GarageCars          0
# GarageArea          0
# GarageQual         81
# GarageCond         81
# PavedDrive          0
# WoodDeckSF          0
# OpenPorchSF         0
# EnclosedPorch       0
# 3SsnPorch           0
# ScreenPorch         0
# PoolArea            0
# PoolQC           1453
# Fence            1179
# MiscFeature      1406
# MiscVal             0
# MoSold              0
# YrSold              0
# SaleType            0
# SaleCondition       0
# SalePrice           0
# LogSalePrice        0
# dtype: int64

# %% [markdown]
# ###### We have null values in the dataset mainly in Alley,PoolQC,Fence,MiscFeature
# ###### There are 19 columns with null values

# %%
#pd.reset_option('max_columns')
pd.reset_option('max_rows')

# %% [markdown]
# # Handling the missing values and Feature selection

# %% [markdown]
# ###### Handling missing values for LotFrontage

# %%
df.LotFrontage.value_counts()
# Out:
# 60.0     111
# 80.0      60
# 70.0      58
# 75.0      46
# 50.0      44
#         ...
# 102.0      1
# 144.0      1
# 112.0      1
# 149.0      1
# 153.0      1
# Name: LotFrontage, Length: 106, dtype: int64

# %%
## distribution plot for LotFrontage
 
sns.distplot(df.LotFrontage)
plt.show()

# %%
df['LotFrontage'].mean()  ## getting the mean
# Out:
# 70.98846960167715

# %%
## Checking the percentage of missing values for LotFrontage

print('The Percentage of data missing in LotFrontage is ',df.LotFrontage.isnull().sum()/len(df)*100)
# Out:
# The Percentage of data missing in LotFrontage is  18.32191780821918

# %%
df.loc[df['LotFrontage'].isnull()==True]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0      127         120       RL          NaN     4928   Pave   NaN      IR1
# 4      422          20       RL          NaN    16635   Pave   NaN      IR1
# 6      561          20       RL          NaN    11341   Pave   NaN      IR1
# 16    1154          30       RM          NaN     5890   Pave   NaN      Reg
# 18     270          20       RL          NaN     7917   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1153   222          60       RL          NaN     8068   Pave   NaN      IR1
# 1158   673          20       RL          NaN    11250   Pave   NaN      IR1
# 1161  1301          60       RL          NaN    10762   Pave   NaN      IR1
# 1163   289          20       RL          NaN     9819   Pave   NaN      IR1
# 1167   617          60       RL          NaN     7861   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolQC  Fence MiscFeature MiscVal MoSold  \
# 0            Lvl    AllPub  ...    NaN    NaN         NaN       0      2
# 4            Lvl    AllPub  ...    NaN    NaN         NaN       0      6
# 6            Lvl    AllPub  ...    NaN    NaN         NaN       0      5
# 16           Lvl    AllPub  ...    NaN    NaN         NaN       0      6
# 18           Lvl    AllPub  ...    NaN  GdPrv         NaN       0      5
# ...          ...       ...  ...    ...    ...         ...     ...    ...
# 1153         Lvl    AllPub  ...    NaN    NaN         NaN       0     12
# 1158         Lvl    AllPub  ...    NaN    NaN         NaN       0      6
# 1161         Lvl    AllPub  ...    NaN    NaN         NaN       0      5
# 1163         Lvl    AllPub  ...    NaN  MnPrv         NaN       0      2
# 1167         Lvl    AllPub  ...    NaN    NaN         NaN       0      6
#
#      YrSold SaleType  SaleCondition  SalePrice  LogSalePrice
# 0      2007       WD         Normal     128000      5.107210
# 4      2009       WD         Normal     215000      5.332438
# 6      2010       WD         Normal     121500      5.084576
# 16     2008       WD         Normal     120500      5.080987
# 18     2007       WD         Normal     148000      5.170262
# ...     ...      ...            ...        ...           ...
# 1153   2009    ConLI         Normal     200000      5.301030
# 1158   2006       WD         Normal     165000      5.217484
# 1161   2009       WD         Normal     225000      5.352183
# 1163   2010       WD         Normal     122000      5.086360
# 1167   2006       WD         Normal     183200      5.262925
#
# [214 rows x 82 columns]

# %%
## Replacing the nan values with mean for LotFrontage

df.loc[df['LotFrontage'].isnull()==True,'LotFrontage']=70.0

# %% [markdown]
# ###### Handling the missing values for Alley,PoolQC,Fence,MiscFeature

# %%
## Percentage of missing values in Alley,PoolQC,Fence,MiscFeature
 
d1=df[['Alley','PoolQC','Fence','MiscFeature']]
a=d1.isnull().sum()/len(d1)*100
a
# Out:
# Alley          93.407534
# PoolQC         99.400685
# Fence          79.708904
# MiscFeature    96.232877
# dtype: float64

# %% [markdown]
# ##### More than 80% of the data are missing in Alley,PoolQC,Fence,MiscFeature

# %%
## removing the features

df.drop(['Alley','PoolQC','Fence','MiscFeature'],axis=1,inplace=True)

# %% [markdown]
# ###### Handling the missing values for BsmtQual,BsmtQual,BsmtCond,BsmtExposure,BsmtFinType1,BsmtFinType2

# %%
## Percentage of missing values

d2=df[['BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2']]
b=d2.isnull().sum()/len(d2)*100
b
# Out:
# BsmtQual        2.568493
# BsmtCond        2.568493
# BsmtExposure    2.654110
# BsmtFinType1    2.568493
# BsmtFinType2    2.654110
# dtype: float64

# %%
## Replacing the missing values with 'NA'

df['BsmtQual']=df['BsmtQual'].fillna('NA')
df['BsmtCond']=df['BsmtCond'].fillna('NA')
df['BsmtExposure']=df['BsmtExposure'].fillna('NA')
df['BsmtFinType1']=df['BsmtFinType1'].fillna('NA')
df['BsmtFinType2']=df['BsmtFinType2'].fillna('NA')

# %% [markdown]
# ###### Replacing missing values for MasVnrType

# %%
df.MasVnrType.value_counts()
# Out:
# None       696
# BrkFace    354
# Stone       98
# BrkCmn      13
# Name: MasVnrType, dtype: int64

# %%
## Replacing the missing values with mode

df.loc[df['MasVnrType'].isnull()==True,'MasVnrType']='None'

# %% [markdown]
# ###### Replacing missing values for MasVnrArea

# %%
 sns.distplot(df.MasVnrArea)
# Out:
# <AxesSubplot:xlabel='MasVnrArea', ylabel='Density'>

# %%
## Finding the median

df['MasVnrArea'].median()
# Out:
# 0.0

# %%
## Replacing the missing value by median
df.loc[df['MasVnrArea'].isnull()==True,'MasVnrArea']=0.0

# %% [markdown]
# ###### Handling missing values for GarageType,GarageFinish,GarageQual,GarageCond

# %%
## Percentage of missing values
d3=df[['GarageType','GarageYrBlt','GarageFinish','GarageQual','GarageCond' ]]
c=d3.isnull().sum()/len(d3)*100
c
# Out:
# GarageType      5.479452
# GarageYrBlt     5.479452
# GarageFinish    5.479452
# GarageQual      5.479452
# GarageCond      5.479452
# dtype: float64

# %%
## Replacing the missing values for GarageType,GarageFinish,GarageQual,GarageCond  by NA

df['GarageType']=df['GarageType'].fillna('NA')
df['GarageFinish']=df['GarageFinish'].fillna('NA')
df['GarageQual']=df['GarageQual'].fillna('NA')
df['GarageCond']=df['GarageCond'].fillna('NA')

# %% [markdown]
# ###### Handling the missing value for GarageYrBlt

# %%
sns.distplot(df.GarageYrBlt)
# Out:
# <AxesSubplot:xlabel='GarageYrBlt', ylabel='Density'>

# %%
df.GarageYrBlt.median()
# Out:
# 1980.0

# %%
df.loc[df['GarageYrBlt'].isnull()==True,'GarageYrBlt']=1980.0

# %% [markdown]
# ###### Handling the missing value for Electrical

# %%
df.Electrical.value_counts()
# Out:
# SBrkr    1070
# FuseA      74
# FuseF      21
# FuseP       2
# Mix         1
# Name: Electrical, dtype: int64

# %%
## Replacing the null values with mode
df.loc[df['Electrical'].isnull()==True,'Electrical']='SBrkr'

# %% [markdown]
# ###### Handling the missing values for FireplaceQu

# %%
df.FireplaceQu.value_counts()
# Out:
# Gd    301
# TA    252
# Fa     25
# Ex     21
# Po     18
# Name: FireplaceQu, dtype: int64

# %%
## Replacing the missing values with NA
df.loc[df['FireplaceQu'].isnull()==True,'FireplaceQu']='NA'

# %%
df.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# LogSalePrice     0
# Length: 78, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1168 entries, 0 to 1167
# Data columns (total 78 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1168 non-null   int64
#  1   MSSubClass     1168 non-null   int64
#  2   MSZoning       1168 non-null   object
#  3   LotFrontage    1168 non-null   float64
#  4   LotArea        1168 non-null   int64
#  5   Street         1168 non-null   object
#  6   LotShape       1168 non-null   object
#  7   LandContour    1168 non-null   object
#  8   Utilities      1168 non-null   object
#  9   LotConfig      1168 non-null   object
#  10  LandSlope      1168 non-null   object
#  11  Neighborhood   1168 non-null   object
#  12  Condition1     1168 non-null   object
#  13  Condition2     1168 non-null   object
#  14  BldgType       1168 non-null   object
#  15  HouseStyle     1168 non-null   object
#  16  OverallQual    1168 non-null   int64
#  17  OverallCond    1168 non-null   int64
#  18  YearBuilt      1168 non-null   int64
#  19  YearRemodAdd   1168 non-null   int64
#  20  RoofStyle      1168 non-null   object
#  21  RoofMatl       1168 non-null   object
#  22  Exterior1st    1168 non-null   object
#  23  Exterior2nd    1168 non-null   object
#  24  MasVnrType     1168 non-null   object
#  25  MasVnrArea     1168 non-null   float64
#  26  ExterQual      1168 non-null   object
#  27  ExterCond      1168 non-null   object
#  28  Foundation     1168 non-null   object
#  29  BsmtQual       1168 non-null   object
#  30  BsmtCond       1168 non-null   object
#  31  BsmtExposure   1168 non-null   object
#  32  BsmtFinType1   1168 non-null   object
#  33  BsmtFinSF1     1168 non-null   int64
#  34  BsmtFinType2   1168 non-null   object
#  35  BsmtFinSF2     1168 non-null   int64
#  36  BsmtUnfSF      1168 non-null   int64
#  37  TotalBsmtSF    1168 non-null   int64
#  38  Heating        1168 non-null   object
#  39  HeatingQC      1168 non-null   object
#  40  CentralAir     1168 non-null   object
#  41  Electrical     1168 non-null   object
#  42  1stFlrSF       1168 non-null   int64
#  43  2ndFlrSF       1168 non-null   int64
#  44  LowQualFinSF   1168 non-null   int64
#  45  GrLivArea      1168 non-null   int64
#  46  BsmtFullBath   1168 non-null   int64
#  47  BsmtHalfBath   1168 non-null   int64
#  48  FullBath       1168 non-null   int64
#  49  HalfBath       1168 non-null   int64
#  50  BedroomAbvGr   1168 non-null   int64
#  51  KitchenAbvGr   1168 non-null   int64
#  52  KitchenQual    1168 non-null   object
#  53  TotRmsAbvGrd   1168 non-null   int64
#  54  Functional     1168 non-null   object
#  55  Fireplaces     1168 non-null   int64
#  56  FireplaceQu    1168 non-null   object
#  57  GarageType     1168 non-null   object
#  58  GarageYrBlt    1168 non-null   float64
#  59  GarageFinish   1168 non-null   object
#  60  GarageCars     1168 non-null   int64
#  61  GarageArea     1168 non-null   int64
#  62  GarageQual     1168 non-null   object
#  63  GarageCond     1168 non-null   object
#  64  PavedDrive     1168 non-null   object
#  65  WoodDeckSF     1168 non-null   int64
#  66  OpenPorchSF    1168 non-null   int64
#  67  EnclosedPorch  1168 non-null   int64
#  68  3SsnPorch      1168 non-null   int64
#  69  ScreenPorch    1168 non-null   int64
#  70  PoolArea       1168 non-null   int64
#  71  MiscVal        1168 non-null   int64
#  72  MoSold         1168 non-null   int64
#  73  YrSold         1168 non-null   int64
#  74  SaleType       1168 non-null   object
#  75  SaleCondition  1168 non-null   object
#  76  SalePrice      1168 non-null   int64
#  77  LogSalePrice   1168 non-null   float64
# dtypes: float64(4), int64(35), object(39)
# memory usage: 711.9+ KB

# %% [markdown]
# ###### We have treated  null values now and we see none

# %%
# We are defining numerical & categorical columns
numeric_features = [feature for feature in df.columns if df[feature].dtype != 'O']
categorical_features = [feature for feature in df.columns if df[feature].dtype == 'O']

# print columns
print('We have {} numerical features : {}'.format(len(numeric_features), numeric_features))
print('\nWe have {} categorical features : {}'.format(len(categorical_features), categorical_features))
# Out:
# We have 39 numerical features : ['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice', 'LogSalePrice']
#
# We have 39 categorical features : ['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'SaleType', 'SaleCondition']

# %%
## Lets create a list of column names for categorical and numerical features

cate_feat = list(df.select_dtypes(include = [object]).columns)
num_feat = list(df.select_dtypes(include = [int,float]).columns)

print(cate_feat)
print('\n')
print(num_feat)
# Out:
# ['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'SaleType', 'SaleCondition']
#
#
# ['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice', 'LogSalePrice']

# %%
# Heatmap for all the remaining numerical data including the taget 'SalePrice'
# Define the heatmap parameters
pd.options.display.float_format = "{:,.2f}".format

# Define correlation matrix
corr_matrix = df[num_feat].corr()

# Replace correlation < |0.3| by 0 for a better visibility
corr_matrix[(corr_matrix < 0.3) & (corr_matrix > -0.3)] = 0

# plot the heatmap
sns.heatmap(corr_matrix, vmax=1.0, vmin=-1.0, linewidths=0.1,
            annot_kws={"size": 9, "color": "black"},annot=True)
plt.title("SalePrice Correlation")
# Out:
# Text(0.5, 1.0, 'SalePrice Correlation')

# %% [markdown]
# We can see that, The overall quality of the house and Ground living Area has 0.79 and 0.74 correlation with the SalePrice of the house, followed by Garagecars with 0.64 correlation.

# %%
df.corr()['SalePrice'].sort_values()
# Out:
# KitchenAbvGr    -0.13
# EnclosedPorch   -0.12
# OverallCond     -0.07
# MSSubClass      -0.06
# YrSold          -0.05
# LowQualFinSF    -0.03
# Id              -0.02
# MiscVal         -0.01
# BsmtHalfBath    -0.01
# BsmtFinSF2      -0.01
# 3SsnPorch        0.06
# MoSold           0.07
# ScreenPorch      0.10
# PoolArea         0.10
# BedroomAbvGr     0.16
# BsmtFullBath     0.21
# BsmtUnfSF        0.22
# LotArea          0.25
# HalfBath         0.30
# WoodDeckSF       0.32
# LotFrontage      0.32
# 2ndFlrSF         0.33
# OpenPorchSF      0.34
# BsmtFinSF1       0.36
# GarageYrBlt      0.45
# Fireplaces       0.46
# MasVnrArea       0.46
# YearRemodAdd     0.51
# YearBuilt        0.51
# TotRmsAbvGrd     0.53
# FullBath         0.55
# 1stFlrSF         0.59
# TotalBsmtSF      0.60
# GarageArea       0.62
# GarageCars       0.63
# GrLivArea        0.71
# OverallQual      0.79
# LogSalePrice     0.95
# SalePrice        1.00
# Name: SalePrice, dtype: float64

# %%
## Lets visualize individually as wew want the highest 10

corr =df.corr()["SalePrice"].sort_values(ascending = False)[2:11] ## selecting cols other than Saleprice, LogPrice
corr
# Out:
# OverallQual    0.79
# GrLivArea      0.71
# GarageCars     0.63
# GarageArea     0.62
# TotalBsmtSF    0.60
# 1stFlrSF       0.59
# FullBath       0.55
# TotRmsAbvGrd   0.53
# YearBuilt      0.51
# Name: SalePrice, dtype: float64

# %%
f,ax = plt.subplots(nrows = 10,ncols = 1, figsize = (20,40))
for i,col in enumerate(corr.index):    
    sns.scatterplot(x = col, y = "SalePrice", data = df, ax = ax[i], color = 'darkorange')
    ax[i].set_title(f'{col} vs SalePrice')

# %% [markdown]
# We can see the features above are quite linear to the Sale Price suggesting positive correlation

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(data=df, x='GrLivArea', y='SalePrice')
# Out:
# <AxesSubplot:xlabel='GrLivArea', ylabel='SalePrice'>

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(data=df, x='YearBuilt', y='SalePrice')
# Out:
# <AxesSubplot:xlabel='YearBuilt', ylabel='SalePrice'>

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(data=df, x='OverallQual', y='SalePrice')
# Out:
# <AxesSubplot:xlabel='OverallQual', ylabel='SalePrice'>

# %% [markdown]
# ### Bivariate analysis to see which year were most of the houses built (Top 10), and does the year built say anything regarding the sale price..

# %%
f, ax = plt.subplots(figsize=(16, 8))
fig = sns.boxplot(x="YearBuilt", y="SalePrice", data=df,)
fig.axis(ymin=0, ymax=900000);
plt.xticks(rotation=90);
plt.tight_layout()

# %%
yr_built = pd.DataFrame({"Count":df["YearBuilt"].value_counts()[:10]}).reset_index()
yr_built.rename(columns={'index':'Year'},inplace=True)
plt.figure(figsize = (20,10))
sns.barplot(x = 'Year', y = "Count", data = yr_built)
plt.title("Year Built")
# Out:
# Text(0.5, 1.0, 'Year Built')

# %% [markdown]
# We see that 2007 followed by 2005 is when most houses were built

# %%
## As a side question, lets see if there is a huge difference in sale price based on different months

df.groupby("MoSold").mean()["SalePrice"].sort_values(ascending = False).plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='MoSold'>

# %% [markdown]
# We dont see a huge difference in sale price

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Univarient Analysis

# %%
## Getting the features with object datatype
dtype_objects = list(columns for columns in df.select_dtypes([object]).columns)

# %%
dtype_objects
# Out:
# ['MSZoning',
#  'Street',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'SaleType',
#  'SaleCondition']

# %%
len(dtype_objects)
# Out:
# 39

# %%
## countplot for datatype with objects

plt.figure(figsize=(15,150))
plotnumber=1
for c in dtype_objects:
    ax=plt.subplot(20,2,plotnumber)
    b= sns.countplot(x=df[c],palette='Set2')
    plt.xticks(rotation=70)
    plotnumber+=1
    for bar in b.patches:
        b.annotate(format(bar.get_height()),
            (bar.get_x() + bar.get_width() / 2,
            bar.get_height()), ha='center', va='center',
            size=10, xytext=(0, 6),textcoords='offset points')
plt.show()

# %% [markdown]
# ###### Count plot for the datatype object has been plotted

# %%
## Getting the features with float datatype

dtype_float =list(columns for columns in df.select_dtypes([float]).columns)

# %%
dtype_float
# Out:
# ['LotFrontage', 'MasVnrArea', 'GarageYrBlt', 'LogSalePrice']

# %%
## Distribution plot 

plt.figure(figsize=(15,150))
plotnumber=1
for a in dtype_float:
    ax=plt.subplot(20,2,plotnumber)
    sns.distplot(x=df[a],color='purple')
    plt.xticks(rotation=70)
    plotnumber+=1
plt.show()

# %% [markdown]
# ###### From the graph LotFrontage gives normal distribution but MasVnrArea and GarageYrBlt is skewed

# %%
## Pie plot for CentralAir

plt.figure(figsize=(5,5))
labels=['Y','N']
size=df['CentralAir'].value_counts()
colors=['lightgreen','lightslategray']
explode=[0,0.3]
plt.pie(size,labels=labels,colors=colors,explode=explode,autopct='%.2f%%',shadow = True,startangle = -30,
wedgeprops= {'edgecolor':'white','linewidth':1})
plt.legend(labels,loc="upper right",title='Category') ## used to label at the side
plt.show()

# %% [markdown]
# ###### From the graph 93.49% houses has CentralAir and 6.51% houses has no CentralAir

# %%
## Donut chart for GarageFinish

plt.figure(figsize=(5,5))
labels=['Fin','RFn','Unf','NA']
size=df['GarageFinish'].value_counts()
colors=['purple','lightblue','pink','yellow']
explode=[0,0.1,0,0]
plt.pie(size,labels=labels,colors=colors,explode=explode,autopct='%.2f%%',shadow=True)
circle = plt.Circle( (0,0),0.8, color='white')
p=plt.gcf()
p.gca().add_artist(circle)
plt.show()

# %% [markdown]
# ###### From the graph for 41.44% of the houses the interior finish of the garage is finished.

# %% [markdown]
# # **Bivarient and Multivarient Analysis**

# %%
## Countplot for CentralAir and BedroomAbvGr

plt.figure(figsize=(15,9))
sns.countplot(x='CentralAir',hue='BedroomAbvGr',palette='terrain',data=df).set(title="BedroomAbvGr vs CentralAir")
plt.show()

# %% [markdown]
# ### The houses with 3 bedrooms has more central air conditioning than others.

# %%
## Scatter plot for GarageArea and GarageYrBlt

sns.scatterplot(x='GarageArea',y='GarageYrBlt',data=df,color='lightcoral')
plt.show()

# %% [markdown]
# **We can see there are some outliers present while comparing garage area and garage year built**

# %%
data=df

# %%
## barplot for saleprice and the data type with objects

plt.figure(figsize=(20,150),facecolor='white')
plotnumber=1
for c in dtype_objects:
    ax=plt.subplot(20,2,plotnumber)
    sns.barplot(x=data[c],y=data.SalePrice,palette='Set3')
    plotnumber+=1
    plt.xticks(rotation=70)
plt.show()

# %%
## bar plot for Electrical,MSSubClass,CentralAir

plt.figure(figsize=(15,9))
splot=sns.barplot(x='Electrical',y='MSSubClass',hue='CentralAir',palette='nipy_spectral',data=data)
plt.show()

# %% [markdown]
# **Building with 2-STORY 1946 & NEWER and Standard Circuit Breakers & Romex use more central air conditioning than others.**

# %%
## Getting the continuous data features

box=df[['LotArea','YearBuilt','BsmtFinSF1','1stFlrSF','2ndFlrSF','LotFrontage', 'MasVnrArea', 'GarageYrBlt']]

# %%
plt.figure(figsize=(15,15),facecolor='white')

plotnum=1 #counter

for c in box:
    if(plotnum<9):
        a=plt.subplot(4,2,plotnum)#plotting 8 graph
        sns.distplot(box[c])#to know distribution
    plotnum+=1#increment counter
plt.tight_layout()

# %% [markdown]
# # Finding the outliers

# %%
## getting the continuous data features

box=df[['LotArea','YearBuilt','BsmtFinSF1','1stFlrSF','2ndFlrSF','LotFrontage', 'MasVnrArea', 'GarageYrBlt']]

# %%
box
# Out:
#       LotArea  YearBuilt  BsmtFinSF1  1stFlrSF  2ndFlrSF  LotFrontage  \
# 0        4928       1976         120       958         0        70.00
# 1       15865       1970         351      2217         0        95.00
# 2        9920       1996         862      1127       886        92.00
# 3       11751       1977         705      1844         0       105.00
# 4       16635       1977        1246      1602         0        70.00
# ...       ...        ...         ...       ...       ...          ...
# 1163     9819       1967         450       900         0        70.00
# 1164     8777       1949           0      1126         0        67.00
# 1165     2280       1976         566       855       601        24.00
# 1166     8500       1920           0       649       668        50.00
# 1167     7861       2002         457       807       702        70.00
#
#       MasVnrArea  GarageYrBlt
# 0           0.00     1,977.00
# 1           0.00     1,970.00
# 2           0.00     1,997.00
# 3         480.00     1,977.00
# 4         126.00     1,977.00
# ...          ...          ...
# 1163       31.00     1,970.00
# 1164        0.00     2,002.00
# 1165        0.00     1,976.00
# 1166        0.00     1,920.00
# 1167        0.00     2,002.00
#
# [1168 rows x 8 columns]

# %%
## boxplot to find the outliers

plt.figure(figsize=(10,30),facecolor='white')
plotnumber=1
for c in box:
    ax=plt.subplot(8,1,plotnumber)
    sns.boxplot(data[c],color='green')
    plotnumber=plotnumber + 1 
plt.show()

# %% [markdown]
# # Handling the skewness

# %%
from scipy.stats import skew

numerical_features = data.dtypes[data.dtypes != 'object'].index

# checking the skewness in all the numerical features
skewed_features = df[numerical_features].apply(lambda x: skew(x.dropna())).sort_values(ascending = False)

# converting the features into a dataframe
skewness = pd.DataFrame({'skew':skewed_features})

# checking the head of skewness dataset
skewness
# Out:
#                skew
# MiscVal       23.04
# PoolArea      13.23
# LotArea       10.65
# 3SsnPorch      9.76
# LowQualFinSF   8.66
# BsmtFinSF2     4.36
# KitchenAbvGr   4.36
# BsmtHalfBath   4.26
# ScreenPorch    4.10
# EnclosedPorch  3.04
# MasVnrArea     2.83
# LotFrontage    2.73
# OpenPorchSF    2.41
# SalePrice      1.95
# BsmtFinSF1     1.87
# TotalBsmtSF    1.74
# 1stFlrSF       1.51
# WoodDeckSF     1.50
# GrLivArea      1.45
# MSSubClass     1.42
# BsmtUnfSF      0.91
# 2ndFlrSF       0.82
# Fireplaces     0.67
# HalfBath       0.66
# TotRmsAbvGrd   0.64
# BsmtFullBath   0.63
# OverallCond    0.58
# BedroomAbvGr   0.24
# MoSold         0.22
# GarageArea     0.19
# OverallQual    0.17
# YrSold         0.12
# LogSalePrice   0.07
# FullBath       0.06
# Id             0.03
# GarageCars    -0.36
# YearRemodAdd  -0.50
# YearBuilt     -0.58
# GarageYrBlt   -0.67

# %%
##applying box-cox transformation - Power transformer 

skewness = skewness[abs(skewness > 0.8)]

# printing how many features are to be box-cox transformed
print("There are {} skewed numerical features to box cox transform".format(skewness.shape[0]))

# importing box-cox1p
from scipy.special import boxcox1p

# defining skewed features
skewed_features = skewness.index

lamda = 0.15
for features in skewed_features:
    df[features] += 1
    df[features] = boxcox1p(df[features], lamda)
df[skewed_features] = np.log1p(df[skewed_features])
print('Skewness has been Handled using Box Cox Transformation')
# Out:
# There are 39 skewed numerical features to box cox transform
# Skewness has been Handled using Box Cox Transformation

# %% [markdown]
# ### Changing categorical data to numerical data

# %%
#getting all the categorical feature

data_object = df.select_dtypes(include = "object").columns
print (data_object)
# Out:
# Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
#Label Encoding to convert categorical data to numerical data

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

for features in data_object:
    df[features] = le.fit_transform(df[features].astype(str))

print (df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1168 entries, 0 to 1167
# Data columns (total 78 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1168 non-null   float64
#  1   MSSubClass     1168 non-null   float64
#  2   MSZoning       1168 non-null   int32
#  3   LotFrontage    1168 non-null   float64
#  4   LotArea        1168 non-null   float64
#  5   Street         1168 non-null   int32
#  6   LotShape       1168 non-null   int32
#  7   LandContour    1168 non-null   int32
#  8   Utilities      1168 non-null   int32
#  9   LotConfig      1168 non-null   int32
#  10  LandSlope      1168 non-null   int32
#  11  Neighborhood   1168 non-null   int32
#  12  Condition1     1168 non-null   int32
#  13  Condition2     1168 non-null   int32
#  14  BldgType       1168 non-null   int32
#  15  HouseStyle     1168 non-null   int32
#  16  OverallQual    1168 non-null   float64
#  17  OverallCond    1168 non-null   float64
#  18  YearBuilt      1168 non-null   float64
#  19  YearRemodAdd   1168 non-null   float64
#  20  RoofStyle      1168 non-null   int32
#  21  RoofMatl       1168 non-null   int32
#  22  Exterior1st    1168 non-null   int32
#  23  Exterior2nd    1168 non-null   int32
#  24  MasVnrType     1168 non-null   int32
#  25  MasVnrArea     1168 non-null   float64
#  26  ExterQual      1168 non-null   int32
#  27  ExterCond      1168 non-null   int32
#  28  Foundation     1168 non-null   int32
#  29  BsmtQual       1168 non-null   int32
#  30  BsmtCond       1168 non-null   int32
#  31  BsmtExposure   1168 non-null   int32
#  32  BsmtFinType1   1168 non-null   int32
#  33  BsmtFinSF1     1168 non-null   float64
#  34  BsmtFinType2   1168 non-null   int32
#  35  BsmtFinSF2     1168 non-null   float64
#  36  BsmtUnfSF      1168 non-null   float64
#  37  TotalBsmtSF    1168 non-null   float64
#  38  Heating        1168 non-null   int32
#  39  HeatingQC      1168 non-null   int32
#  40  CentralAir     1168 non-null   int32
#  41  Electrical     1168 non-null   int32
#  42  1stFlrSF       1168 non-null   float64
#  43  2ndFlrSF       1168 non-null   float64
#  44  LowQualFinSF   1168 non-null   float64
#  45  GrLivArea      1168 non-null   float64
#  46  BsmtFullBath   1168 non-null   float64
#  47  BsmtHalfBath   1168 non-null   float64
#  48  FullBath       1168 non-null   float64
#  49  HalfBath       1168 non-null   float64
#  50  BedroomAbvGr   1168 non-null   float64
#  51  KitchenAbvGr   1168 non-null   float64
#  52  KitchenQual    1168 non-null   int32
#  53  TotRmsAbvGrd   1168 non-null   float64
#  54  Functional     1168 non-null   int32
#  55  Fireplaces     1168 non-null   float64
#  56  FireplaceQu    1168 non-null   int32
#  57  GarageType     1168 non-null   int32
#  58  GarageYrBlt    1168 non-null   float64
#  59  GarageFinish   1168 non-null   int32
#  60  GarageCars     1168 non-null   float64
#  61  GarageArea     1168 non-null   float64
#  62  GarageQual     1168 non-null   int32
#  63  GarageCond     1168 non-null   int32
#  64  PavedDrive     1168 non-null   int32
#  65  WoodDeckSF     1168 non-null   float64
#  66  OpenPorchSF    1168 non-null   float64
#  67  EnclosedPorch  1168 non-null   float64
#  68  3SsnPorch      1168 non-null   float64
#  69  ScreenPorch    1168 non-null   float64
#  70  PoolArea       1168 non-null   float64
#  71  MiscVal        1168 non-null   float64
#  72  MoSold         1168 non-null   float64
#  73  YrSold         1168 non-null   float64
#  74  SaleType       1168 non-null   int32
#  75  SaleCondition  1168 non-null   int32
#  76  SalePrice      1168 non-null   float64
#  77  LogSalePrice   1168 non-null   float64
# dtypes: float64(39), int32(39)
# memory usage: 533.9 KB
# None

# %% [markdown]
# # Feature Scaling

# %%
df1=pd.read_csv('test.csv') # assigning a name to test data

# %%
## Treating if there is any null values in test data

pd.options.display.max_rows=None ## shows all the rows
df1.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage       45
# LotArea            0
# Street             0
# Alley            278
# LotShape           0
# LandContour        0
# Utilities          0
# LotConfig          0
# LandSlope          0
# Neighborhood       0
# Condition1         0
# Condition2         0
# BldgType           0
# HouseStyle         0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# RoofStyle          0
# RoofMatl           0
# Exterior1st        0
# Exterior2nd        0
# MasVnrType         1
# MasVnrArea         1
# ExterQual          0
# ExterCond          0
# Foundation         0
# BsmtQual           7
# BsmtCond           7
# BsmtExposure       7
# BsmtFinType1       7
# BsmtFinSF1         0
# BsmtFinType2       7
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# Heating            0
# HeatingQC          0
# CentralAir         0
# Electrical         1
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       0
# BsmtHalfBath       0
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# KitchenQual        0
# TotRmsAbvGrd       0
# Functional         0
# Fireplaces         0
# FireplaceQu      139
# GarageType        17
# GarageYrBlt       17
# GarageFinish      17
# GarageCars         0
# GarageArea         0
# GarageQual        17
# GarageCond        17
# PavedDrive         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# PoolQC           292
# Fence            248
# MiscFeature      282
# MiscVal            0
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# dtype: int64

# %%
df1.drop(['Alley','PoolQC','Fence','MiscFeature'],axis=1,inplace=True)

# %%
## Replacing the missing values with NA
df1.loc[df1['FireplaceQu'].isnull()==True,'FireplaceQu']='NA'

# %%
df1=df1.dropna(axis=0)

# %%
df1['SalePrice']=np.nan # adding the target column with nulls as test dataset didn't have

# %% [markdown]
# # Splitting Train and Test Data (Blank SalePrice Values are included in Test Data)

# %%
x_train = df.drop(["SalePrice"], axis=1)

# %%
y_train = df["SalePrice"]

# %%
x_test = df1.drop(["SalePrice"], axis=1)

# %%
y_test = df["SalePrice"]

# %% [markdown]
# # **Model Evaluation**
# ## Linear Regression

# %%
## importing the library

from sklearn.linear_model import LinearRegression

# %%
LR=LinearRegression()
LR.fit(x_train,y_train)  ## fitting the training data

x_test_pred_LR=LR.predict(x_test)  ## predicted x test

# %%
x_test_pred_LR
# Out:
# array([3.58225096, 3.51073145, 3.47679707, 3.57476195, 3.43600779,
#        3.43058714, 3.64094753, 3.5206022 , 3.79807657, 3.5305856 ,
#        3.58903708, 3.5133536 , 3.60258812, 3.49633842, 3.49144597,
#        3.52558075, 3.57358263, 3.49816668, 3.53052435, 3.53754812,
#        3.55020587, 3.52578819, 3.47791423, 3.55743616, 3.56887349,
#        3.55205181, 3.56134753, 3.42981331, 3.66393621, 3.49095835,
#        3.47625511, 3.59310777, 3.53806694, 3.62039416, 3.68710741,
#        3.55840556, 3.63922834, 3.48062436, 3.62837988, 3.66478797,
#        3.61418271, 3.50589042, 3.54898038, 3.63996597, 3.69948546,
#        3.48975852, 3.4984038 , 3.50357549, 3.55653948, 3.43066761,
#        3.70460304, 3.53847227, 3.55165969, 3.46097382, 3.63578788,
#        3.49694587, 3.51018815, 3.6128836 , 3.51817865, 3.48449789,
#        3.51651608, 3.5130942 , 3.51238947, 3.56367854, 3.576521  ,
#        3.5396283 , 3.50907391, 3.60121882, 3.51841819, 3.60235501,
#        3.57183799, 3.48859701, 3.4261631 , 3.69480319, 3.48052507,
#        3.6196079 , 3.51211506, 3.41723619, 3.66106128, 3.54063465,
#        3.51968591, 3.51480323, 3.47367356, 3.52540617, 3.58330729,
#        3.56853036, 3.46915173, 3.58428319, 3.56883095, 3.51400697,
#        3.58197672, 3.5732347 , 3.57032333, 3.5820461 , 3.55671323,
#        3.53978034, 3.59289366, 3.56884069, 3.49859192, 3.54665398,
#        3.62669112, 3.58083639, 3.49267123, 3.54201851, 3.46974523,
#        3.62686928, 3.52342785, 3.47185377, 3.56278908, 3.50300373,
#        3.44216226, 3.49031176, 3.5731773 , 3.49263031, 3.56788549,
#        3.53758586, 3.69443526, 3.51003422, 3.57624159, 3.63328498,
#        3.52176262, 3.52741305, 3.50474689, 3.55987565, 3.59371236,
#        3.60237066, 3.70620579, 3.57107938, 3.5815039 , 3.56389733,
#        3.58655178, 3.57688864, 3.52320004, 3.5671103 , 3.48609073,
#        3.59276365, 3.51912756, 3.56206986, 3.47270847, 3.56013216,
#        3.54088625, 3.52529047, 3.59665578, 3.53263878, 3.47602014,
#        3.54923136, 3.58293527, 3.52640004, 3.6628148 , 3.59455786,
#        3.56401991, 3.68584135, 3.61270037, 3.5272529 , 3.544049  ,
#        3.61970337, 3.44031593, 3.60581192, 3.52862692, 3.5475291 ,
#        3.45428062, 3.52285533, 3.5790118 , 3.50543716, 3.60722735,
#        3.48720813, 3.55803355, 3.62990626, 3.58819454, 3.56426177,
#        3.55914497, 3.55469179, 3.57908874, 3.56002077, 3.48199834,
#        3.51780048, 3.51295809, 3.61231267, 3.48095765, 3.51099515,
#        3.65972831, 3.55348944, 3.48708539, 3.65452174, 3.42484538,
#        3.55935351, 3.46986325, 3.57740589, 3.57683318, 3.53876757,
#        3.51674588, 3.56025968, 3.59342424, 3.52962561, 3.50260996,
#        3.5224877 , 3.41902802, 3.5251579 , 3.55461271, 3.49566756,
#        3.51845689, 3.57227109, 3.49266637, 3.49949288, 3.54277418,
#        3.58131563, 3.54309249, 3.65903763, 3.63622931, 3.38869548,
#        3.54151077, 3.62105561, 3.44712886, 3.4768337 , 3.69381325,
#        3.50666359, 3.42493551, 3.65111192, 3.61987674, 3.42211709,
#        3.57056585, 3.47670268, 3.48759844, 3.50414204, 3.59293721,
#        3.64186131, 3.60608134, 3.57323038, 3.51282637, 3.5342849 ,
#        3.43620601, 3.53774819, 3.48567275, 3.52391863, 3.61911399,
#        3.50989226, 3.51456984, 3.48780673, 3.42611018, 3.54038563,
#        3.47706617, 3.56391503, 3.57558134, 3.60101256, 3.56473762,
#        3.55334188, 3.57164471, 3.5691913 , 3.54356825, 3.57502938,
#        3.56520606, 3.63073228, 3.45997533, 3.71487911, 3.60597829,
#        3.59597512, 3.47806699, 3.56000212, 3.74814591, 3.54600285,
#        3.55699013, 3.47378385, 3.50927471, 3.47244769, 3.69371869,
#        3.68840994, 3.67442007, 3.39041045, 3.62015376, 3.61709831,
#        3.49964404, 3.60901986, 3.5263513 , 3.56464162, 3.46661316,
#        3.60795847, 3.54740859, 3.59708735, 3.57765169, 3.47415648,
#        3.53102064, 3.65994755, 3.56043129, 3.51957543, 3.57679587,
#        3.51812949, 3.4886859 , 3.66403045, 3.75340968, 3.51653599,
#        3.42685599, 3.46226559])

# %%
y_test ## tested y
# Out:
# 529    3.58
# 491    3.51
# 459    3.48
# 279    3.57
# 655    3.44
#        ...
# 326    3.66
# 440    3.76
# 1387   3.51
# 1323   3.43
# 61     3.46
# Name: SalePrice, Length: 292, dtype: float64

# %%
x_train_pred_LR=LR.predict(x_train) ##predicted x train

x_train_pred_LR
# Out:
# array([3.66059537, 3.47663109, 3.54662469, ..., 3.47932418, 3.60831821,
#        3.59878531])

# %%
y_train  ## trained y
# Out:
# 618    3.66
# 870    3.48
# 92     3.55
# 817    3.63
# 302    3.59
#        ...
# 763    3.67
# 835    3.50
# 1216   3.48
# 559    3.61
# 684    3.60
# Name: SalePrice, Length: 1168, dtype: float64

# %%
print('Linear Regression trainind score is',LR.score(x_train,y_train))
# Out:
# Linear Regression trainind score is 0.9998270692514184

# %%
print('Linear Regression testing score is',LR.score(x_test,y_test))
# Out:
# Linear Regression testing score is 0.9997997133114862

# %% [markdown]
# # Evaluation Metrics for Linear Regression

# %%
from sklearn.metrics import r2_score
train_score=r2_score(y_train,x_train_pred_LR)
print('Linear Regression r2_score for training is',train_score)
# Out:
# Linear Regression r2_score for training is 0.9998270692514184

# %%
test_score=r2_score(y_test,x_test_pred_LR)
print('Linear Regression r2_score for testing is',test_score)
# Out:
# Linear Regression r2_score for testing is 0.9997997133114862

# %% [markdown]
# #### Training score is more than testing score so the model is underfitting.

# %% [markdown]
# # Random Forest Regressor

# %%
## Importing the library

from sklearn.ensemble import RandomForestRegressor
RF=RandomForestRegressor()
RF.fit(x_train,y_train) ## fitting the data

x_test_pred_RF=RF.predict(x_test)  ## predicted x test

# %%
x_test_pred_RF
# Out:
# array([3.58226245, 3.51038708, 3.47700858, 3.57465048, 3.43730284,
#        3.43168874, 3.64230187, 3.52088946, 3.77692255, 3.53019077,
#        3.58912043, 3.51550201, 3.60200024, 3.49653327, 3.49080948,
#        3.52553199, 3.57267944, 3.49781417, 3.53076982, 3.53717377,
#        3.54894428, 3.52491371, 3.47700695, 3.55733925, 3.56798929,
#        3.55117808, 3.56100023, 3.43071084, 3.66224987, 3.49010154,
#        3.47703821, 3.59249365, 3.53828091, 3.62016699, 3.6900491 ,
#        3.55831147, 3.63850215, 3.48104578, 3.62905434, 3.66601932,
#        3.61610342, 3.5063998 , 3.54804228, 3.63992975, 3.70306854,
#        3.49076635, 3.49945957, 3.50372578, 3.55583411, 3.43122784,
#        3.70598868, 3.53819613, 3.55116306, 3.46023262, 3.63661777,
#        3.49635498, 3.50893248, 3.61307586, 3.51805   , 3.48471352,
#        3.51625978, 3.51300101, 3.51246884, 3.56389265, 3.57607126,
#        3.5394168 , 3.50902324, 3.60194803, 3.51808172, 3.60198806,
#        3.57167435, 3.48945915, 3.42596618, 3.6981735 , 3.48020692,
#        3.61927442, 3.51244767, 3.42039401, 3.66214466, 3.54048734,
#        3.51936601, 3.51502104, 3.47297027, 3.52551387, 3.58168228,
#        3.56806914, 3.46895661, 3.5837236 , 3.56888686, 3.51429885,
#        3.58166599, 3.57267746, 3.57049655, 3.5816432 , 3.55581874,
#        3.53951513, 3.59262199, 3.56807047, 3.49866847, 3.54596451,
#        3.62703265, 3.58046222, 3.49227808, 3.54198255, 3.47042532,
#        3.62699063, 3.52310254, 3.47177262, 3.56223643, 3.5022303 ,
#        3.44170691, 3.49010417, 3.57265116, 3.4924133 , 3.56698185,
#        3.53722575, 3.69334648, 3.51042212, 3.57624916, 3.63339434,
#        3.52071436, 3.52693508, 3.50449267, 3.55941698, 3.59332706,
#        3.59988088, 3.70862367, 3.57073598, 3.58164346, 3.56321917,
#        3.58656177, 3.57656883, 3.52310735, 3.5662605 , 3.4867249 ,
#        3.59283535, 3.51889403, 3.5623574 , 3.47394195, 3.55943669,
#        3.54168552, 3.52554749, 3.59575808, 3.53260607, 3.47532893,
#        3.54853933, 3.58240786, 3.52603418, 3.66213919, 3.59429753,
#        3.56393587, 3.68865982, 3.61249366, 3.52690607, 3.54410918,
#        3.62018252, 3.44041429, 3.60579886, 3.52790428, 3.54706464,
#        3.45484774, 3.52192924, 3.57895577, 3.50491648, 3.60742427,
#        3.48495028, 3.55835445, 3.63035142, 3.58779382, 3.56431168,
#        3.55935195, 3.55443271, 3.57808062, 3.55940347, 3.48117452,
#        3.51807761, 3.51299312, 3.6131817 , 3.48036824, 3.51148509,
#        3.66103183, 3.55301157, 3.48672948, 3.65488254, 3.42749197,
#        3.55833544, 3.47061883, 3.57654123, 3.57665348, 3.53815375,
#        3.51697582, 3.560231  , 3.59318893, 3.5292073 , 3.50219118,
#        3.52244438, 3.42002449, 3.52553853, 3.55450836, 3.49617543,
#        3.51808059, 3.57165018, 3.49305429, 3.49807961, 3.5427959 ,
#        3.58153073, 3.54272664, 3.65843445, 3.63660141, 3.38422457,
#        3.54166488, 3.62057801, 3.44761167, 3.4761916 , 3.69144141,
#        3.50489272, 3.42739029, 3.65287975, 3.6202492 , 3.42209842,
#        3.57032858, 3.47707182, 3.48746991, 3.50451259, 3.59281389,
#        3.64272692, 3.60581738, 3.57270734, 3.51300359, 3.53376372,
#        3.43733535, 3.53723417, 3.48488774, 3.52430082, 3.61927111,
#        3.50971055, 3.51430216, 3.48781042, 3.42590834, 3.54027317,
#        3.47695601, 3.56430753, 3.57494481, 3.60091013, 3.56440867,
#        3.55325678, 3.57042679, 3.56889195, 3.54280176, 3.57453537,
#        3.56472259, 3.63092618, 3.46031327, 3.71939406, 3.60504309,
#        3.59557849, 3.47773533, 3.55932918, 3.75998246, 3.54270805,
#        3.55586851, 3.47377754, 3.50841717, 3.47114979, 3.69190374,
#        3.68918259, 3.67586043, 3.38271643, 3.62022439, 3.61704453,
#        3.49949175, 3.60850824, 3.52553799, 3.56418186, 3.46623487,
#        3.60780104, 3.54704717, 3.59779408, 3.57697665, 3.47366848,
#        3.53132173, 3.66009029, 3.56100216, 3.51935596, 3.57659864,
#        3.51692652, 3.48946145, 3.6659786 , 3.76732973, 3.51429389,
#        3.42769028, 3.46414225])

# %%
y_test   ## y test
# Out:
# 529    3.58
# 491    3.51
# 459    3.48
# 279    3.57
# 655    3.44
#        ...
# 326    3.66
# 440    3.76
# 1387   3.51
# 1323   3.43
# 61     3.46
# Name: SalePrice, Length: 292, dtype: float64

# %%
x_train_pred_RF=LR.predict(x_train)  ## predicted x train
x_train_pred_RF
# Out:
# array([3.66059537, 3.47663109, 3.54662469, ..., 3.47932418, 3.60831821,
#        3.59878531])

# %%
y_train  ## y train
# Out:
# 618    3.66
# 870    3.48
# 92     3.55
# 817    3.63
# 302    3.59
#        ...
# 763    3.67
# 835    3.50
# 1216   3.48
# 559    3.61
# 684    3.60
# Name: SalePrice, Length: 1168, dtype: float64

# %% [markdown]
# ### Random Foresr Regressor Score

# %%
print('Training score for Random Forest Regressor is',RF.score(x_train,y_train))
# Out:
# Training score for Random Forest Regressor is 0.9998863520405027

# %%
print('Testing score for Random Forest Regressor is',RF.score(x_test,y_test))
# Out:
# Testing score for Random Forest Regressor is 0.999059338163104

# %% [markdown]
# Testing score for Random Forest Regressor is 0.8734354150958835

# %% [markdown]
# **Training score is more than Testing score,so the Random Forest Regressor model is underfitting.So we can do hyper parametric tuning.**

# %% [markdown]
# # Hyper parametric Tuning -- Random Forest Regressor

# %%
from sklearn.model_selection import RandomizedSearchCV

random_grid = {'n_estimators': [100,200,300,400,500,600],  ## no. of trees
               'max_features': ['auto', 'sqrt'],  
               'max_depth': [10, 15,20,25], ## maxinum number of levels in trees 
               'min_samples_split':  [2, 5, 10], ## minimum number of samples required to split a node
               'min_samples_leaf': [1, 2, 4], ## Minimum number of samples required at each leaf node
               'bootstrap': [True, False]}  ##  Method of selecting samples for training each tree

# %%
hyper_tuning=RandomizedSearchCV(estimator=RF,param_distributions=random_grid,n_iter=10,cv=5,verbose=5,random_state=2)

# %%
hyper_tuning.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500;, score=0.955 total time=   1.2s
# [CV 2/5] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500;, score=0.899 total time=   1.2s
# [CV 3/5] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500;, score=0.910 total time=   1.2s
# [CV 4/5] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500;, score=0.933 total time=   1.2s
# [CV 5/5] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=500;, score=0.941 total time=   1.3s
# [CV 1/5] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.959 total time=   0.5s
# [CV 2/5] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.908 total time=   0.5s
# [CV 3/5] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.915 total time=   0.5s
# [CV 4/5] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.937 total time=   0.6s
# [CV 5/5] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.947 total time=   0.5s
# [CV 1/5] END bootstrap=True, max_depth=25, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=400;, score=0.999 total time=   3.4s
# [CV 2/5] END bootstrap=True, max_depth=25, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=400;, score=0.993 total time=   3.4s
# [CV 3/5] END bootstrap=True, max_depth=25, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=400;, score=0.996 total time=   3.5s
# [CV 4/5] END bootstrap=True, max_depth=25, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=400;, score=0.996 total time=   3.4s
# [CV 5/5] END bootstrap=True, max_depth=25, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=400;, score=1.000 total time=   3.5s
# [CV 1/5] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=0.999 total time=   0.9s
# [CV 2/5] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=0.994 total time=   0.9s
# [CV 3/5] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=0.996 total time=   0.9s
# [CV 4/5] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=0.996 total time=   0.9s
# [CV 5/5] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=1.000 total time=   0.9s
# [CV 1/5] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=300;, score=0.956 total time=   0.7s
# [CV 2/5] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=300;, score=0.902 total time=   0.7s
# [CV 3/5] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=300;, score=0.910 total time=   0.7s
# [CV 4/5] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=300;, score=0.940 total time=   0.7s
# [CV 5/5] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=300;, score=0.942 total time=   0.7s
# [CV 1/5] END bootstrap=False, max_depth=15, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=0.999 total time=   2.6s
# [CV 2/5] END bootstrap=False, max_depth=15, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=0.998 total time=   2.6s
# [CV 3/5] END bootstrap=False, max_depth=15, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=0.998 total time=   2.6s
# [CV 4/5] END bootstrap=False, max_depth=15, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=0.995 total time=   2.6s
# [CV 5/5] END bootstrap=False, max_depth=15, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=1.000 total time=   2.6s
# [CV 1/5] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=0.961 total time=   0.5s
# [CV 2/5] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=0.902 total time=   0.5s
# [CV 3/5] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=0.913 total time=   0.5s
# [CV 4/5] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=0.942 total time=   0.6s
# [CV 5/5] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=0.949 total time=   0.5s
# [CV 1/5] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400;, score=0.960 total time=   1.2s
# [CV 2/5] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400;, score=0.907 total time=   1.2s
# [CV 3/5] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400;, score=0.916 total time=   1.2s
# [CV 4/5] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400;, score=0.945 total time=   1.2s
# [CV 5/5] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400;, score=0.951 total time=   1.2s
# [CV 1/5] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=0.953 total time=   0.7s
# [CV 2/5] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=0.897 total time=   0.7s
# [CV 3/5] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=0.910 total time=   0.7s
# [CV 4/5] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=0.937 total time=   0.7s
# [CV 5/5] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=300;, score=0.939 total time=   0.7s
# [CV 1/5] END bootstrap=False, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=1.000 total time=   3.2s
# [CV 2/5] END bootstrap=False, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.999 total time=   3.1s
# [CV 3/5] END bootstrap=False, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.999 total time=   3.1s
# [CV 4/5] END bootstrap=False, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.998 total time=   3.2s
# [CV 5/5] END bootstrap=False, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=1.000 total time=   3.2s
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(),
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_depth': [10, 15, 20, 25],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500, 600]},
#                    random_state=2, verbose=5)

# %%
hyper_tuning.best_params_  ## getting the best parameters
# Out:
# {'n_estimators': 200,
#  'min_samples_split': 5,
#  'min_samples_leaf': 1,
#  'max_features': 'auto',
#  'max_depth': 10,
#  'bootstrap': False}

# %%
RF_hyper_tuning=RandomForestRegressor(n_estimators=600,min_samples_split=2,min_samples_leaf= 1,max_features='sqrt',max_depth=30,bootstrap= False)  ## implementing the best parameters

# %%
RF_hyper_tuning.fit(x_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=False, max_depth=30, max_features='sqrt',
#                       n_estimators=600)

# %%
RF_hyper_pred_test=RF_hyper_tuning.predict(x_test) ## predicted hyperparametric tuning x test

RF_hyper_pred_test
# Out:
# array([3.59391837, 3.51558073, 3.4806793 , 3.58120649, 3.44351968,
#        3.45477763, 3.62390255, 3.50982377, 3.7459066 , 3.53366378,
#        3.58771614, 3.52138147, 3.60458295, 3.50135228, 3.49553214,
#        3.525647  , 3.58676673, 3.48186875, 3.5243325 , 3.53740154,
#        3.51967155, 3.52570837, 3.46999534, 3.55393979, 3.57257713,
#        3.56380395, 3.55847223, 3.42411573, 3.66293573, 3.48772329,
#        3.49942358, 3.58775385, 3.52771134, 3.6369504 , 3.67381399,
#        3.56191646, 3.6372357 , 3.48851272, 3.61696603, 3.65594589,
#        3.60164479, 3.50730987, 3.55676957, 3.64859834, 3.67412935,
#        3.50855536, 3.50096807, 3.50605906, 3.55356597, 3.45468504,
#        3.68767201, 3.53226498, 3.55111085, 3.43946028, 3.62339243,
#        3.4909323 , 3.50353032, 3.60863888, 3.51764988, 3.47636059,
#        3.5225651 , 3.5121223 , 3.52013019, 3.54868635, 3.58389896,
#        3.53586209, 3.50487034, 3.60074993, 3.51455222, 3.59040575,
#        3.56631012, 3.4926801 , 3.43163791, 3.6189069 , 3.45378814,
#        3.62241943, 3.51296936, 3.45747759, 3.64551541, 3.53699307,
#        3.51502577, 3.5125274 , 3.48224126, 3.52666389, 3.57379611,
#        3.57040403, 3.47041488, 3.58180907, 3.56575464, 3.51746529,
#        3.57881028, 3.5700953 , 3.56767024, 3.58963291, 3.56922642,
#        3.53599848, 3.59145917, 3.55685973, 3.4971623 , 3.53424362,
#        3.62390015, 3.58192194, 3.49545323, 3.53700106, 3.4751741 ,
#        3.63178948, 3.5298654 , 3.46688402, 3.56016063, 3.48671292,
#        3.45242241, 3.49279503, 3.57340841, 3.49500036, 3.55544428,
#        3.53486711, 3.70227512, 3.50776206, 3.5781508 , 3.62616051,
#        3.50453508, 3.5396087 , 3.50926545, 3.56745224, 3.59760538,
#        3.60895837, 3.6940766 , 3.57506492, 3.57920165, 3.55639986,
#        3.5818526 , 3.58073554, 3.51415253, 3.56819329, 3.47946538,
#        3.60221647, 3.51686608, 3.56458941, 3.47602354, 3.56528408,
#        3.52973079, 3.52379848, 3.59671162, 3.52598867, 3.4913479 ,
#        3.55678569, 3.59169008, 3.52419694, 3.64532726, 3.60144181,
#        3.55426996, 3.68597088, 3.62054211, 3.52940379, 3.53766209,
#        3.61992642, 3.48001115, 3.57530713, 3.48774012, 3.55018602,
#        3.47977303, 3.52389116, 3.57607391, 3.49935222, 3.61246333,
#        3.48295405, 3.55308324, 3.63995682, 3.582087  , 3.56084243,
#        3.55409121, 3.5476725 , 3.5777516 , 3.556705  , 3.4851094 ,
#        3.50084947, 3.51239545, 3.61018935, 3.48446849, 3.51788921,
#        3.63234063, 3.56162547, 3.48258531, 3.65484581, 3.46689631,
#        3.55863841, 3.46205637, 3.57759481, 3.57995249, 3.52621947,
#        3.52279047, 3.55073749, 3.59124075, 3.52227433, 3.50063044,
#        3.52225739, 3.43061921, 3.52150699, 3.54958266, 3.49881381,
#        3.51406652, 3.57394623, 3.48607024, 3.49285442, 3.5184633 ,
#        3.56679609, 3.53802284, 3.65841069, 3.6290212 , 3.38952939,
#        3.53652195, 3.62276262, 3.44332199, 3.45897133, 3.6667069 ,
#        3.54549308, 3.52792887, 3.63162889, 3.61831238, 3.43008063,
#        3.57436535, 3.50917386, 3.49283422, 3.50050032, 3.58482924,
#        3.63698216, 3.60809519, 3.58477969, 3.51402985, 3.54266293,
#        3.44747106, 3.52553776, 3.47191331, 3.52288502, 3.60924547,
#        3.50418664, 3.51367462, 3.49044672, 3.43918316, 3.54679621,
#        3.47569004, 3.56682652, 3.57954673, 3.60051403, 3.55605285,
#        3.54771203, 3.57484784, 3.56964688, 3.52468912, 3.57565507,
#        3.56030113, 3.62674096, 3.44826149, 3.68890774, 3.60484419,
#        3.60147115, 3.46395967, 3.57457106, 3.70212254, 3.60898172,
#        3.56690983, 3.49084172, 3.5072132 , 3.46367688, 3.70254913,
#        3.67547962, 3.65393612, 3.40259681, 3.59096387, 3.61768582,
#        3.5026133 , 3.59295842, 3.51828541, 3.56127914, 3.4808223 ,
#        3.60847916, 3.56906121, 3.57131148, 3.58501726, 3.47125111,
#        3.51881815, 3.67682627, 3.54710862, 3.51695964, 3.57807097,
#        3.51846306, 3.48557964, 3.64832906, 3.72447734, 3.52714409,
#        3.40856655, 3.45774677])

# %%
RF_hyper_pred_train=RF_hyper_tuning.predict(x_train)  ## predicted hyper parametric tuning x train

RF_hyper_pred_train
# Out:
# array([3.65995718, 3.47620275, 3.54651016, ..., 3.48018103, 3.60880129,
#        3.5989052 ])

# %% [markdown]
# ### Score after Random Forest Regressor Hyper Parametric Tuning

# %%
print('Training score for Random Forest Regressor Hyper Parametric Tuning is ',RF_hyper_tuning.score(x_train,y_train))
# Out:
# Training score for Random Forest Regressor Hyper Parametric Tuning is  1.0

# %%
print('Testing score for Random Forest Regressor Hyper Parametric Tuning is ',RF_hyper_tuning.score(x_test,y_test))
# Out:
# Testing score for Random Forest Regressor Hyper Parametric Tuning is  0.9515722883909419

# %% [markdown]
# # Decision Tree Regressor

# %%
## Importing the library

from sklearn.tree import DecisionTreeRegressor
DT=DecisionTreeRegressor()
DT.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
x_test_pred_DT=DT.predict(x_test) ## predicted x test

x_test_pred_DT  ## predicted x test
# Out:
# array([3.58245295, 3.51039005, 3.47700581, 3.57449452, 3.43755724,
#        3.43140396, 3.64190742, 3.52124766, 3.77697651, 3.53028646,
#        3.58964119, 3.51558551, 3.60193526, 3.49666629, 3.49085334,
#        3.52552538, 3.57267414, 3.49652334, 3.53110617, 3.53662334,
#        3.54863144, 3.52552538, 3.47700581, 3.55736315, 3.56803594,
#        3.55114258, 3.56034098, 3.43140396, 3.66172115, 3.49011267,
#        3.47700581, 3.59169864, 3.53831148, 3.62023614, 3.68762393,
#        3.55836156, 3.63855422, 3.48174689, 3.6322379 , 3.6654288 ,
#        3.61603821, 3.5063872 , 3.54810359, 3.63978958, 3.70223064,
#        3.49085334, 3.49950045, 3.50366565, 3.5557534 , 3.43140396,
#        3.70186485, 3.53831148, 3.55124641, 3.46018513, 3.63668404,
#        3.49652334, 3.50906614, 3.61318051, 3.51812521, 3.48483639,
#        3.51622398, 3.51300751, 3.51226822, 3.56375046, 3.57629559,
#        3.53935202, 3.50906614, 3.60193526, 3.51812521, 3.60193526,
#        3.57175657, 3.48936878, 3.42502337, 3.69777486, 3.48018103,
#        3.61907676, 3.51235689, 3.42041256, 3.66222768, 3.54053665,
#        3.51938105, 3.51494465, 3.47295241, 3.52552538, 3.58170928,
#        3.56803594, 3.47047367, 3.58374381, 3.56873979, 3.51365566,
#        3.58062909, 3.57267414, 3.57037087, 3.58158689, 3.55585445,
#        3.5394277 , 3.59169864, 3.56803594, 3.49879629, 3.54597569,
#        3.62700884, 3.58150004, 3.49232516, 3.5421144 , 3.47047367,
#        3.62700884, 3.5230941 , 3.4713039 , 3.56229762, 3.50228848,
#        3.44055353, 3.49011267, 3.57267414, 3.49232516, 3.5670929 ,
#        3.53718791, 3.69155946, 3.51039005, 3.57629559, 3.63320056,
#        3.52062772, 3.52672816, 3.50435011, 3.55935415, 3.5933268 ,
#        3.59968733, 3.70223064, 3.57083403, 3.58158689, 3.56317081,
#        3.58671814, 3.57629559, 3.5230941 , 3.56614461, 3.48862165,
#        3.59292123, 3.51925588, 3.56249205, 3.47295241, 3.55935415,
#        3.54163843, 3.52552538, 3.59653692, 3.53232839, 3.47539591,
#        3.54863144, 3.58245295, 3.52582687, 3.66276545, 3.59413505,
#        3.56375046, 3.68877845, 3.61245847, 3.52672816, 3.54295124,
#        3.62023614, 3.44154085, 3.60581752, 3.52792252, 3.54703232,
#        3.45480059, 3.52248084, 3.57852038, 3.50503183, 3.60818647,
#        3.48483639, 3.55836156, 3.6322379 , 3.58671814, 3.564232  ,
#        3.55935415, 3.55433226, 3.57807775, 3.55935415, 3.48174689,
#        3.51812521, 3.51300751, 3.61318051, 3.48018103, 3.51170379,
#        3.66005925, 3.55330985, 3.48772078, 3.65563666, 3.42717651,
#        3.55836156, 3.46880109, 3.57629559, 3.57629559, 3.53831148,
#        3.51686008, 3.56034098, 3.5933268 , 3.52910858, 3.50228848,
#        3.52201944, 3.42063493, 3.52552538, 3.55433226, 3.49523143,
#        3.51812521, 3.57175657, 3.49305636, 3.49808923, 3.54273314,
#        3.58150004, 3.54273314, 3.65730878, 3.63668404, 3.38902932,
#        3.54163843, 3.62023614, 3.44829819, 3.47620275, 3.69155946,
#        3.50503183, 3.42717651, 3.65281232, 3.62023614, 3.42502337,
#        3.57037087, 3.47700581, 3.48636053, 3.50435011, 3.5933268 ,
#        3.64223346, 3.60581752, 3.57267414, 3.51300751, 3.53377209,
#        3.43755724, 3.53662334, 3.48483639, 3.52431407, 3.61884839,
#        3.50972938, 3.51417242, 3.48862165, 3.42502337, 3.54042608,
#        3.47700581, 3.56519099, 3.57449452, 3.60193526, 3.56375046,
#        3.55320727, 3.57037087, 3.5685055 , 3.54382086, 3.57449452,
#        3.56519099, 3.63000989, 3.46018513, 3.71729322, 3.60506328,
#        3.59574008, 3.47780514, 3.55935415, 3.75730747, 3.54273314,
#        3.55585445, 3.47377078, 3.50773191, 3.4713039 , 3.69155946,
#        3.68996892, 3.67716412, 3.38769078, 3.62023614, 3.61674515,
#        3.49950045, 3.60731598, 3.52552538, 3.564232  , 3.46574883,
#        3.60731598, 3.5475741 , 3.5977252 , 3.57692148, 3.47377078,
#        3.53133965, 3.66005925, 3.56034098, 3.51938105, 3.57629559,
#        3.51686008, 3.48936878, 3.6654288 , 3.77331885, 3.51397882,
#        3.42717651, 3.46368347])

# %%
y_test ## y test
# Out:
# 529    3.58
# 491    3.51
# 459    3.48
# 279    3.57
# 655    3.44
#        ...
# 326    3.66
# 440    3.76
# 1387   3.51
# 1323   3.43
# 61     3.46
# Name: SalePrice, Length: 292, dtype: float64

# %%
x_train_pred_DT=DT.predict(x_train)  ## predicted x train

x_train_pred_DT
# Out:
# array([3.65995718, 3.47620275, 3.54651016, ..., 3.48018103, 3.60880129,
#        3.5989052 ])

# %%
y_train ## y train
# Out:
# 618    3.66
# 870    3.48
# 92     3.55
# 817    3.63
# 302    3.59
#        ...
# 763    3.67
# 835    3.50
# 1216   3.48
# 559    3.61
# 684    3.60
# Name: SalePrice, Length: 1168, dtype: float64

# %%
print('Training score for Decision Tree Regressor is',DT.score(x_train,y_train))
# Out:
# Training score for Decision Tree Regressor is 1.0

# %%
print('Testing score for Decision Tree Regressor is',DT.score(x_test,y_test))
# Out:
# Testing score for Decision Tree Regressor is 0.9989626109084527

# %% [markdown]
# ### Training score is more than the Testing score,so the decision tree model is underfitting,So we can do hyper parametric tuning.

# %% [markdown]
# **Hyper parametric Tuning-- Decision Tree**

# %%
from sklearn.model_selection import RandomizedSearchCV

parameters={"splitter":["best","random"],
            "max_depth" : [2,4,6,8],
           "min_samples_leaf":[1,2,3,4,5,],
           "max_features":["auto","sqrt"],
           "max_leaf_nodes":[5,10,15] }

# %%
hyper_tuning_DT = RandomizedSearchCV(estimator=DT, param_distributions = parameters,
                               cv = 2, n_iter = 10, n_jobs=-1)

# %%
hyper_tuning_DT.fit(x_train, y_train)
# Out:
# RandomizedSearchCV(cv=2, estimator=DecisionTreeRegressor(), n_jobs=-1,
#                    param_distributions={'max_depth': [2, 4, 6, 8],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'max_leaf_nodes': [5, 10, 15],
#                                         'min_samples_leaf': [1, 2, 3, 4, 5],
#                                         'splitter': ['best', 'random']})

# %%
hyper_tuning_DT.best_params_
# Out:
# {'splitter': 'best',
#  'min_samples_leaf': 3,
#  'max_leaf_nodes': 15,
#  'max_features': 'auto',
#  'max_depth': 6}

# %%
hypertuning_DT = DecisionTreeRegressor(splitter= 'best',min_samples_leaf=5,max_leaf_nodes=15,max_features='sqrt',max_depth=6)

hypertuning_DT
# Out:
# DecisionTreeRegressor(max_depth=6, max_features='sqrt', max_leaf_nodes=15,
#                       min_samples_leaf=5)

# %%
hypertuning_DT.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=6, max_features='sqrt', max_leaf_nodes=15,
#                       min_samples_leaf=5)

# %%
DT_hyper_pred_xtest=hypertuning_DT.predict(x_test)

DT_hyper_pred_xtest
# Out:
# array([3.57741715, 3.51451257, 3.51451257, 3.57741715, 3.50449037,
#        3.50449037, 3.57282868, 3.51451257, 3.67424298, 3.57282868,
#        3.57960382, 3.50449037, 3.59671668, 3.51451257, 3.51451257,
#        3.50449037, 3.62248204, 3.49607795, 3.50449037, 3.51451257,
#        3.47091543, 3.57960382, 3.50449037, 3.57960382, 3.57741715,
#        3.54296813, 3.57282868, 3.43221779, 3.67424298, 3.47091543,
#        3.50449037, 3.62248204, 3.54296813, 3.62248204, 3.67424298,
#        3.57960382, 3.57960382, 3.50449037, 3.62248204, 3.67424298,
#        3.57741715, 3.54296813, 3.57960382, 3.67424298, 3.67386839,
#        3.50449037, 3.50449037, 3.50449037, 3.57741715, 3.50449037,
#        3.67424298, 3.50449037, 3.57741715, 3.51451257, 3.62248204,
#        3.50449037, 3.50449037, 3.59671668, 3.50449037, 3.43221779,
#        3.50449037, 3.50449037, 3.51451257, 3.54296813, 3.62248204,
#        3.54296813, 3.50449037, 3.57282868, 3.57741715, 3.59671668,
#        3.57960382, 3.51451257, 3.47091543, 3.57960382, 3.50449037,
#        3.62248204, 3.50449037, 3.50449037, 3.59671668, 3.50449037,
#        3.50449037, 3.50449037, 3.50449037, 3.57282868, 3.51451257,
#        3.57282868, 3.47091543, 3.57960382, 3.57282868, 3.50449037,
#        3.57282868, 3.57741715, 3.57960382, 3.57282868, 3.57960382,
#        3.51451257, 3.57282868, 3.57741715, 3.50449037, 3.57741715,
#        3.57282868, 3.59671668, 3.51451257, 3.50449037, 3.43221779,
#        3.62248204, 3.57282868, 3.47091543, 3.57960382, 3.50449037,
#        3.51451257, 3.50449037, 3.57741715, 3.54296813, 3.57282868,
#        3.57741715, 3.67424298, 3.50449037, 3.51451257, 3.62248204,
#        3.49607795, 3.57282868, 3.50449037, 3.57741715, 3.57282868,
#        3.57960382, 3.67424298, 3.57960382, 3.57282868, 3.57741715,
#        3.57282868, 3.57282868, 3.50449037, 3.57741715, 3.50449037,
#        3.67424298, 3.51451257, 3.57282868, 3.50449037, 3.57282868,
#        3.51451257, 3.57282868, 3.57741715, 3.50449037, 3.50449037,
#        3.57960382, 3.57282868, 3.50449037, 3.67424298, 3.57960382,
#        3.57741715, 3.67424298, 3.57282868, 3.50449037, 3.51451257,
#        3.57741715, 3.50449037, 3.54296813, 3.49607795, 3.57960382,
#        3.50449037, 3.50449037, 3.57282868, 3.50449037, 3.57960382,
#        3.50449037, 3.57741715, 3.62248204, 3.57960382, 3.59671668,
#        3.54296813, 3.57741715, 3.57960382, 3.57960382, 3.47091543,
#        3.50449037, 3.50449037, 3.57741715, 3.47091543, 3.50449037,
#        3.54296813, 3.57741715, 3.47091543, 3.67424298, 3.47091543,
#        3.54296813, 3.50449037, 3.57282868, 3.57960382, 3.57960382,
#        3.57282868, 3.51451257, 3.57282868, 3.57282868, 3.50449037,
#        3.57282868, 3.43221779, 3.50449037, 3.54296813, 3.50449037,
#        3.50449037, 3.57960382, 3.51451257, 3.50449037, 3.50449037,
#        3.50449037, 3.51451257, 3.67424298, 3.59671668, 3.47091543,
#        3.57282868, 3.57282868, 3.47091543, 3.43221779, 3.62533785,
#        3.62533785, 3.57741715, 3.57741715, 3.57282868, 3.43221779,
#        3.57741715, 3.54296813, 3.50449037, 3.50449037, 3.57960382,
#        3.62248204, 3.59671668, 3.57741715, 3.51451257, 3.57741715,
#        3.47091543, 3.50449037, 3.51451257, 3.49607795, 3.62248204,
#        3.51451257, 3.50449037, 3.50449037, 3.50449037, 3.57741715,
#        3.47091543, 3.59671668, 3.59671668, 3.59671668, 3.57741715,
#        3.57282868, 3.54296813, 3.57282868, 3.51451257, 3.57282868,
#        3.54296813, 3.62248204, 3.47091543, 3.67424298, 3.57282868,
#        3.59671668, 3.50449037, 3.57960382, 3.67386839, 3.67424298,
#        3.57282868, 3.51451257, 3.47091543, 3.50449037, 3.67424298,
#        3.67424298, 3.57741715, 3.43221779, 3.51451257, 3.57282868,
#        3.50449037, 3.51451257, 3.50449037, 3.57741715, 3.47091543,
#        3.57282868, 3.57282868, 3.51451257, 3.59671668, 3.36373494,
#        3.50449037, 3.67424298, 3.51451257, 3.51451257, 3.57960382,
#        3.47091543, 3.50449037, 3.67386839, 3.67424298, 3.51451257,
#        3.43221779, 3.50449037])

# %%
y_test
# Out:
# 529    3.58
# 491    3.51
# 459    3.48
# 279    3.57
# 655    3.44
#        ...
# 326    3.66
# 440    3.76
# 1387   3.51
# 1323   3.43
# 61     3.46
# Name: SalePrice, Length: 292, dtype: float64

# %%
DT_hyper_pred_xtrain=hypertuning_DT.predict(x_train)

DT_hyper_pred_xtrain
# Out:
# array([3.67424298, 3.50449037, 3.50449037, ..., 3.50449037, 3.57960382,
#        3.57282868])

# %%
y_train
# Out:
# 618    3.66
# 870    3.48
# 92     3.55
# 817    3.63
# 302    3.59
#        ...
# 763    3.67
# 835    3.50
# 1216   3.48
# 559    3.61
# 684    3.60
# Name: SalePrice, Length: 1168, dtype: float64

# %%
print('Training score for hyper parametric tuning of Decision tree regressor is',hypertuning_DT.score(x_train,y_train))
# Out:
# Training score for hyper parametric tuning of Decision tree regressor is 0.7226957358981887

# %%
print('Testing score for hyper parametric tuning of Decision tree regressor is',hypertuning_DT.score(x_test,y_test))
# Out:
# Testing score for hyper parametric tuning of Decision tree regressor is 0.6817640166246073

# %% [markdown]
# ## Xtreme Gradient Boosting

# %%
from xgboost import XGBRegressor
XGB=XGBRegressor()
XGB.fit(x_train,y_train) 

xtest_XGB_pred=XGB.predict(x_test) ## predicted x test

# %%
xtest_XGB_pred
# Out:
# array([3.5804195, 3.5103054, 3.4764278, 3.5748086, 3.4349697, 3.4344463,
#        3.643563 , 3.5222733, 3.8059235, 3.5314527, 3.5899923, 3.515817 ,
#        3.6016371, 3.49926  , 3.491044 , 3.5255287, 3.5726929, 3.4991171,
#        3.5315993, 3.5365124, 3.5473175, 3.5243623, 3.4761117, 3.5577767,
#        3.568932 , 3.551433 , 3.5605288, 3.4326615, 3.658815 , 3.4897733,
#        3.4766014, 3.591814 , 3.5388033, 3.6194303, 3.6911347, 3.5589206,
#        3.6374202, 3.4811525, 3.6310985, 3.668719 , 3.615722 , 3.5071023,
#        3.547313 , 3.6381884, 3.7007473, 3.4914076, 3.4996274, 3.5029616,
#        3.5561726, 3.4345105, 3.7138174, 3.539015 , 3.5519536, 3.4583936,
#        3.635957 , 3.4984612, 3.509807 , 3.6133192, 3.5179055, 3.4842527,
#        3.5162833, 3.5121827, 3.5120094, 3.5627384, 3.575459 , 3.5390275,
#        3.5093818, 3.6014178, 3.5179567, 3.601737 , 3.5711436, 3.4908044,
#        3.4254634, 3.7006123, 3.4809659, 3.6184475, 3.5118768, 3.4192393,
#        3.658722 , 3.5413747, 3.5187583, 3.5153887, 3.4737575, 3.525392 ,
#        3.580147 , 3.5689344, 3.4674492, 3.584907 , 3.569075 , 3.5152574,
#        3.580663 , 3.5724843, 3.5704672, 3.5806177, 3.5560067, 3.5387404,
#        3.5915914, 3.568124 , 3.499072 , 3.5454433, 3.6273654, 3.581936 ,
#        3.4920545, 3.5418465, 3.4705794, 3.627245 , 3.5235474, 3.4707537,
#        3.5630283, 3.502452 , 3.4380844, 3.4896064, 3.572673 , 3.4921923,
#        3.5664792, 3.536183 , 3.693582 , 3.5102835, 3.5753922, 3.634959 ,
#        3.521974 , 3.5266805, 3.504948 , 3.5592124, 3.5941536, 3.601072 ,
#        3.7160509, 3.5709665, 3.5803459, 3.5633414, 3.5872633, 3.575551 ,
#        3.523715 , 3.5663626, 3.4851959, 3.5918458, 3.5184603, 3.5628765,
#        3.4735782, 3.559192 , 3.5412524, 3.5255296, 3.5956237, 3.5332205,
#        3.473253 , 3.5473769, 3.5806086, 3.5261173, 3.6597946, 3.593967 ,
#        3.563212 , 3.69171  , 3.6125534, 3.5269964, 3.5441546, 3.6200974,
#        3.4396114, 3.6070495, 3.5277495, 3.5467165, 3.4544554, 3.5225008,
#        3.5786095, 3.5046809, 3.607601 , 3.4840162, 3.55866  , 3.630858 ,
#        3.5879235, 3.5647502, 3.5594645, 3.5539935, 3.5777464, 3.5591571,
#        3.479509 , 3.518231 , 3.5117917, 3.6128259, 3.4810297, 3.5112782,
#        3.6593783, 3.55413  , 3.4852467, 3.655505 , 3.4242916, 3.5598526,
#        3.4710917, 3.5754883, 3.5754364, 3.5384135, 3.51696  , 3.560347 ,
#        3.5942638, 3.527822 , 3.5026805, 3.522861 , 3.4142292, 3.5253623,
#        3.5539832, 3.4941607, 3.5178561, 3.571234 , 3.492503 , 3.4991686,
#        3.5423772, 3.581958 , 3.5420501, 3.658355 , 3.6364079, 3.3886101,
#        3.541293 , 3.6197445, 3.448696 , 3.4757469, 3.688561 , 3.5050821,
#        3.426125 , 3.6521063, 3.6193795, 3.4190342, 3.5707612, 3.476498 ,
#        3.4881763, 3.5049398, 3.5914528, 3.6434488, 3.6069832, 3.5730648,
#        3.5121827, 3.5343082, 3.43897  , 3.5363169, 3.4843442, 3.5245595,
#        3.6181283, 3.5100524, 3.5154092, 3.487923 , 3.4228644, 3.5409641,
#        3.476589 , 3.5646846, 3.5750382, 3.6007679, 3.5644994, 3.55352  ,
#        3.570517 , 3.5687783, 3.54238  , 3.5750892, 3.5665903, 3.6317613,
#        3.458817 , 3.7143033, 3.6031985, 3.595088 , 3.4767466, 3.559463 ,
#        3.7575817, 3.542195 , 3.5560927, 3.47424  , 3.509104 , 3.4712346,
#        3.6868088, 3.6906593, 3.6768086, 3.3903909, 3.6193397, 3.6167872,
#        3.499829 , 3.6090796, 3.5254736, 3.564325 , 3.4690983, 3.6087685,
#        3.5472298, 3.5967846, 3.5765817, 3.4738598, 3.5310915, 3.6589677,
#        3.5604537, 3.5190327, 3.5753598, 3.517228 , 3.4903703, 3.6674793,
#        3.7583406, 3.5152278, 3.4194086, 3.4598181], dtype=float32)

# %%
xtrain_XGB_pred=XGB.predict(x_train)

# %%
xtrain_XGB_pred
# Out:
# array([3.6601756, 3.4765882, 3.5458307, ..., 3.4809775, 3.6091924,
#        3.5997462], dtype=float32)

# %%
print('Training score for XGB is',XGB.score(x_train,y_train))
# Out:
# Training score for XGB is 0.9999337232252173

# %%
print('Testing score for XGB is',XGB.score(x_test,y_test))
# Out:
# Testing score for XGB is 0.9994552530996582

# %%
x_XGB_pred=XGB.predict(x)

# %% [markdown]
# # **OUTPUT**

# %%
data=pd.read_csv('../input/house-prices-advanced-regression-techniques/train.csv')

# %%
Conclusion = pd.DataFrame({'Id': data.Id, 'SalePrice': x_XGB_pred})

# %%
Conclusion
# Out:
#         Id  SalePrice
# 0        1       3.80
# 1        2       3.78
# 2        3       3.80
# 3        4       3.81
# 4        5       3.81
# ...    ...        ...
# 1455  1456       3.80
# 1456  1457       3.78
# 1457  1458       3.80
# 1458  1459       3.77
# 1459  1460       3.78
#
# [1460 rows x 2 columns]

# %%
# save the prediction
Conclusion.to_csv('Conclusion.csv', index=False)
